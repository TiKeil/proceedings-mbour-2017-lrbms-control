# %%
import os
import sys
import time

sys.path.append(os.getcwd() + '/../scripts/')

# %%
# for interactive plots
#%matplotlib notebook

# else
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (8.0, 6.0)
mpl.rcParams['font.size'] = 12
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['figure.subplot.bottom'] = .1 

from mpl_toolkits.mplot3d import Axes3D # required for 3d plots
from matplotlib import cm # required for colors

import matplotlib.pyplot as plt

from functools import partial

import numpy as np
np.seterr(all='raise')

from scipy.optimize import minimize

# %%
from pymor.core.logger import set_log_levels, getLogger
set_log_levels({'online_adaptive_lrbms': 'DEBUG',
                'OS2015_academic_problem': 'INFO',
                'local_thermalblock_problem': 'INFO',
                'senegal_proceedings_problem': 'INFO',
                'discretize_elliptic': 'INFO',
                'offline': 'INFO',
                'online_enrichment': 'INFO',
                'lrbms': 'INFO',
                'notebook': 'INFO'})
logger = getLogger('notebook.notebook')

# %% [markdown]
# # setting up the problem

# %% [markdown]
# For $\mu \in \mathcal{P}$, find $u(\mu) \in H^1_0(\Omega)$, s.t.
#
# $- \nabla \cdot \big( \lambda(\mu) \nabla u(\mu) \big) = f$
#
# with
#
# $\begin{align}
# \Omega &= [-1, 1]^2,\\
# \mathcal{P} &= [0, \pi]^2,\\
# f(x, y) &= \tfrac{1}{2} \pi^2 cos(\tfrac{1}{2} \pi x) cos(\tfrac{1}{2} \pi y),\\
# \lambda(\mu) &= \theta_0(\mu) \lambda_0 + \theta_1(\mu) \lambda_1,\\
# \theta_0(\mu) &= 1.1 + sin(\mu_0)\mu_1,\\
# \theta_1(\mu) &= 1.1 + sin(\mu_1),\\
# \lambda_0 &= \chi_{\Omega \backslash \omega},\\
# \lambda_1 &= \chi_\omega,\\
# \omega &:= [-\tfrac{2}{3}, -\tfrac{1}{3}]^2 \cup ([-\tfrac{2}{3}, -\tfrac{1}{3}] \times [\tfrac{1}{3}, \tfrac{2}{3}])
# \end{align}$
#
# The diffusion is thus given as the linear combination of scaled indicator functions with support inside two blocks $\omega$ in the left half of the domain, roughly where the `w` is here:
#
# ```
# +-----------+
# |           |
# |  w        |
# |           |
# |  w        |
# |           |
# +-----------+
# ```

# %% [markdown]
# ## and the reference discretization
#
# $P^1$ SWIPDG on a conforming simplex grid.

# %%
from senegal_proceedings_problem import init_grid_and_problem

config = {'num_coarse_grid_elements': [8, 8], 
          'num_grid_refinements': 4,
          'num_grid_subdomains': [8, 8], 
          'num_grid_oversampling_layers': 4, # num_grid_oversampling_layers has to exactly cover one subdomain!
          'enrichment_target_error': None,   # this means: 1.1*estimated discretization error
          'marking_doerfler_theta': -1,      # these two ...
          'marking_max_age': -1}             # ... will be set below

grid_and_problem_data = init_grid_and_problem(config)
grid = grid_and_problem_data['grid']
logger.info('... grid has {} elements and {} subdomains'.format(grid.num_elements, grid.num_subdomains))

mu_bar = grid_and_problem_data['mu_bar']
parameter_range = grid_and_problem_data['parameter_range']
parameter_range = (parameter_range[0], parameter_range[1])

initial_guess = np.array([0.25, 0.5])
# Out:
# 00:00 senegal_proceedings_problem: initializing grid and problem ...
# 00:00 notebook: ... grid has 2048 elements and 64 subdomains

# %%
from discretize_elliptic import discretize

block_SWIPDG_disc, block_space = discretize(grid_and_problem_data)
block_SWIPDG_disc.disable_logging()

parameter_space = block_SWIPDG_disc.parameter_space
parameter_type = block_SWIPDG_disc.parameter_type
parse_parameter = block_SWIPDG_disc.parse_parameter
mu_bar = parse_parameter(mu_bar)

logger.info('reference discretization has {} DoFs'.format(block_SWIPDG_disc.solution_space.dim))
# Out:
# 00:00 discretize_block_SWIPDG: discretizing ...
# 01:06 notebook: reference discretization has 6144 DoFs

# %% [markdown]
# # minimizing using the reference discretization

# %%
def compute_value_matrix(f, x, y):
    f_of_x = np.zeros((len(x), len(y)))
    for ii in range(len(x)):
        for jj in range(len(y)):
            f_of_x[ii][jj] = f((x[ii], y[jj]))
    x, y = np.meshgrid(x, y)
    return x, y, f_of_x


def plot_3d_surface(f, x, y):
    X, Y = x, y
    cmaps = [plt.get_cmap(name) for name in ('Purples', 'Oranges', 'Blues')]
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    if isinstance(f, (list, tuple)):
        for ii in range(len(f)):
            x, y, f_of_x = compute_value_matrix(f[ii], X, Y)
            ax.plot_surface(x, y, f_of_x, cmap=cmaps[ii%len(cmaps)],
                            linewidth=0, antialiased=False)
    else:
        x, y, f_of_x = compute_value_matrix(f, x, y)
        ax.plot_surface(x, y, f_of_x, cmap=cmaps[0],
                        linewidth=0, antialiased=False)
    ax.view_init(elev=57.7597402597, azim=-59.6370967742)
    ax.set_xlim3d([-0.10457963, 3.2961723])
    ax.set_ylim3d([-0.10457963, 3.29617229])
    #ax.set_zlim3d([ 1.21122592, 4.42022848])
    return ax


def addplot_xy_point_as_bar(ax, x, y, color='orange', z_range=None):
    ax.plot([y, y], [x, x], z_range if z_range else ax.get_zlim(), color)

# %%
logger.info('computing some reference quantities of interest ...')

training_set = parameter_space.sample_uniformly(25)
training_set = [mu['diffusion'] for mu in training_set]

def reference_quantity_of_interest(mu):
    return block_SWIPDG_disc.rhs.apply(block_SWIPDG_disc.solve(mu)).data[0]

reference_quantities_of_interest = list()
for mu in training_set:
    reference_quantities_of_interest.append(reference_quantity_of_interest(mu))

logger.info('... done')
# Out:
# 01:07 notebook: computing some reference quantities of interest ...
# 01:50 notebook: ... done

# %%
logger.info('plotting ...')

XX = np.linspace(parameter_range[0] + 0.05, parameter_range[1], 10)
YY = XX

plot_3d_surface(reference_quantity_of_interest, XX, YY)

logger.info('... done')
# Out:
# 03:28:29 notebook: plotting ...
# 03:28:36 notebook: ... done

# %%
logger.info('minimizing reference quantity of interest:')

reference_minimization_data = {'num_evals': 0,
                               'evaluations' : [],
                               'evaluation_points': []}


def record_results(function, data, mu):
    print('.', end='')
    QoI = function(mu)
    data['num_evals'] += 1
    # we need to make sure to copy the data, since the added mu will be changed inplace by minimize afterwards
    data['evaluation_points'].append([parse_parameter(mu)['diffusion'][:][0], parse_parameter(mu)['diffusion'][:][1]])
    data['evaluations'].append(QoI[0])
    return QoI


def report(result, data):
    if (result.status != 0):
        logger.info(' failed!')
    else:
        logger.info(' succeded!')
        logger.info('  mu_min:    {}'.format(parse_parameter(result.x)))
        logger.info('  QoI(mu_min): {}'.format(result.fun[0]))
        logger.info('  num iterations:     {}'.format(result.nit))
        logger.info('  num function calls: {}'.format(data['num_evals']))


def extended_report(data):
    for kk, vv in data.items():
        logger.info(kk)
        if isinstance(vv, (list, tuple)):
            for v in vv:
                logger.info('  {}'.format(v))
        else:
            logger.info('  {}'.format(vv))
        logger.info('')


result = minimize(partial(record_results, reference_quantity_of_interest, reference_minimization_data),
                  initial_guess,
                  method='L-BFGS-B', jac=False,
                  bounds=(parameter_range, parameter_range),
                  options={'ftol': 1e-15})

report(result, reference_minimization_data)
# Out:
# 01:57 notebook: minimizing reference quantity of interest:
# ...............................
# 02:00 notebook:  succeded!
# 02:00 notebook:   mu_min:    {diffusion: [1.5709556647769143, 3.141592653589793]}
# 02:00 notebook:   QoI(mu_min): 1.2440146176507332
# 02:00 notebook:   num iterations:     7
# 02:00 notebook:   num function calls: 39
# ........

# %%
logger.info('plotting chosen points during minimization of reference quantity of interest ...')

reference_plot = plot_3d_surface(reference_quantity_of_interest, XX, YY)

for mu in reference_minimization_data['evaluation_points']:
    addplot_xy_point_as_bar(reference_plot, mu[0], mu[1])

logger.info('... done')
# Out:
# 02:00 notebook: plotting chosen points during minimization of reference quantity of interest ...
# 02:07 notebook: ... done

# %%
reference_minimizer = result.x
reference_minimum = result.fun[0]
reference_num_global_solves = reference_minimization_data['num_evals']

logger.info('reference_minimizer: mu = {}'.format(reference_minimizer))
logger.info('reference_minimum: {}'.format(reference_minimum))
logger.info('reference_num_global_solves: {}'.format(reference_num_global_solves))
logger.info('')

extended_report(reference_minimization_data)
# Out:
# 02:07 notebook: reference_minimizer: mu = [ 1.57095566  3.14159265]
# 02:07 notebook: reference_minimum: 1.2440146176507332
# 02:07 notebook: reference_num_global_solves: 39
#
# 02:07 notebook: num_evals
# 02:07 notebook:   39
#
# 02:07 notebook: evaluations
# 02:07 notebook:   3.9716123092896556
# 02:07 notebook:   3.971612294449353
# 02:07 notebook:   3.9716123004735544
# 02:07 notebook:   2.020444126959145
# 02:07 notebook:   2.0204441286987675
# 02:07 notebook:   2.0204441192141385
# 02:07 notebook:   1.5068749271819337
# 02:07 notebook:   1.5068749307174232
# 02:07 notebook:   1.5068749235615588
# 02:07 notebook:   1.2482881414594262
# 02:07 notebook:   1.2482881423306567
# 02:07 notebook:   1.248288139112053
# 02:07 notebook:   1.2444337286401332
# 02:07 notebook:   1.2444337289123315
# 02:07 notebook:   1.244433726297414
# 02:07 notebook:   1.2440146176536413
# 02:07 notebook:   1.2440146176528817
# 02:07 notebook:   1.2440146153081355
# 02:07 notebook:   1.2440146328634547
# 02:07 notebook:   1.2440146328666806
# 02:07 notebook:   1.2440146305243354
# 02:07 notebook:   1.2440146190064494
# 02:07 notebook:   1.2440146190078811
# 02:07 notebook:   1.2440146166630377
# 02:07 notebook:   1.2440146177731135
# 02:07 notebook:   1.2440146177736218
# 02:07 notebook:   1.2440146154306695
# 02:07 notebook:   1.244014617661064
# 02:07 notebook:   1.2440146176614093
# 02:07 notebook:   1.2440146153208835
# 02:07 notebook:   1.2440146176523657
# 02:07 notebook:   1.2440146176528037
# 02:07 notebook:   1.2440146153098568
# 02:07 notebook:   1.24401461765126
# 02:07 notebook:   1.2440146176533895
# 02:07 notebook:   1.2440146153096876
# 02:07 notebook:   1.2440146176507332
# 02:07 notebook:   1.2440146176507934
# 02:07 notebook:   1.2440146153073695
#
# 02:07 notebook: evaluation_points
# 02:07 notebook:   [0.25, 0.5]
# 02:07 notebook:   [0.25000000999999999, 0.5]
# 02:07 notebook:   [0.25, 0.50000001000000005]
# 02:07 notebook:   [1.7340302764440594, 1.3816101182418379]
# 02:07 notebook:   [1.7340302864440593, 1.3816101182418379]
# 02:07 notebook:   [1.7340302764440594, 1.3816101282418378]
# 02:07 notebook:   [1.9217318985637331, 2.4406615172581492]
# 02:07 notebook:   [1.921731908563733, 2.4406615172581492]
# 02:07 notebook:   [1.9217318985637331, 2.4406615272581491]
# 02:07 notebook:   [1.6690392629889157, 3.1415926535897931]
# 02:07 notebook:   [1.6690392729889156, 3.1415926535897931]
# 02:07 notebook:   [1.6690392629889157, 3.1415926635897931]
# 02:07 notebook:   [1.60159989809682, 3.1415926535897931]
# 02:07 notebook:   [1.60159990809682, 3.1415926535897931]
# 02:07 notebook:   [1.60159989809682, 3.1415926635897931]
# 02:07 notebook:   [1.5709556700314427, 3.1415926535897931]
# 02:07 notebook:   [1.5709556800314426, 3.1415926535897931]
# 02:07 notebook:   [1.5709556700314427, 3.1415926635897931]
# 02:07 notebook:   [1.5710409498664468, 3.1415926535897931]
# 02:07 notebook:   [1.5710409598664468, 3.1415926535897931]
# 02:07 notebook:   [1.5710409498664468, 3.1415926635897931]
# 02:07 notebook:   [1.5709650236640489, 3.1415926535897931]
# 02:07 notebook:   [1.5709650336640488, 3.1415926535897931]
# 02:07 notebook:   [1.5709650236640489, 3.1415926635897931]
# 02:07 notebook:   [1.5709565324619907, 3.1415926535897931]
# 02:07 notebook:   [1.5709565424619907, 3.1415926535897931]
# 02:07 notebook:   [1.5709565324619907, 3.1415926635897931]
# 02:07 notebook:   [1.5709557381470647, 3.1415926535897931]
# 02:07 notebook:   [1.5709557481470646, 3.1415926535897931]
# 02:07 notebook:   [1.5709557381470647, 3.1415926635897931]
# 02:07 notebook:   [1.5709556763707224, 3.1415926535897931]
# 02:07 notebook:   [1.5709556863707224, 3.1415926535897931]
# 02:07 notebook:   [1.5709556763707224, 3.1415926635897931]
# 02:07 notebook:   [1.5709556740519608, 3.1415926535897931]
# 02:07 notebook:   [1.5709556840519607, 3.1415926535897931]
# 02:07 notebook:   [1.5709556740519608, 3.1415926635897931]
# 02:07 notebook:   [1.5709556647769143, 3.1415926535897931]
# 02:07 notebook:   [1.5709556747769142, 3.1415926535897931]
# 02:07 notebook:   [1.5709556647769143, 3.1415926635897931]

# %% [markdown]
# To conclude: minimizing using the reference discretization costs
# * 7 global SWIPDG evaluations
# * and addidionally $39 - 7 = 32$ global SWIPDG evaluations for the finite difference approximation of the gradient

# %% [markdown]
# # setting up the standard RB discretization

# %% [markdown]
# Here we apply a standard greedy algorithm to the SWIPDG discretization:
# * single RB with global support
# * standard residual-based a posteriori error estimate on the model reduction error
# * error estimation w.r.t. the energy error (SWIPDG system matrix) for a fixed paramter $\overline{\mu}$
# * Gram-Schmidt basis extension using the product inducing the above norm

# %%
logger.info('reducing with standard RB ...')
logger.info('')

from pymor.algorithms.greedy import greedy
from pymor.discretizations.basic import StationaryDiscretization
from pymor.parameters.functionals import GenericParameterFunctional
from pymor.reductors.coercive import CoerciveRBReductor

from discretize_elliptic import alpha

def coercivity_estimator(mu):
    return 1./np.sqrt(alpha(grid_and_problem_data['lambda']['coefficients'], mu, mu_bar))

SWIPDG_disc = StationaryDiscretization(
    block_SWIPDG_disc.operators['global_op'],
    block_SWIPDG_disc.operators['global_rhs'],
    products={'energy_dg_mu_bar': block_SWIPDG_disc.operators['global_op'].assemble(mu_bar)},
    parameter_space=parameter_space,
    name='SWIPDG')

RB_reductor = CoerciveRBReductor(
    SWIPDG_disc,
    product=SWIPDG_disc.energy_dg_mu_bar_product,
    coercivity_estimator=GenericParameterFunctional(coercivity_estimator, parameter_type))

RB_greedy_data = greedy(SWIPDG_disc, RB_reductor, training_set,
                        extension_params={'method': 'gram_schmidt'},
                        max_extensions=len(training_set))

num_RB_greedy_extensions = RB_greedy_data['extensions']
RB_greedy_mus, RB_greedy_errors = RB_greedy_data['max_err_mus'], RB_greedy_data['max_errs']

logger.info('RB system is of size {}x{}'.format(num_RB_greedy_extensions, num_RB_greedy_extensions))
logger.info('maximum estimated model reduction error over training set: {}'.format(RB_greedy_errors[-1]))

logger.info('')
logger.info('... done')
# Out:
# 02:07 notebook: reducing with standard RB ...
#
# 02:07 greedy: Started greedy search on 625 samples
# 02:07 greedy: Reducing ...
# 02:07 |   CoerciveRBReductor: RB projection ...
# 02:07 |   CoerciveRBReductor: Assembling error estimator ...
# 02:07 |   |   ResidualReductor: Estimating residual range ...
# 02:07 |   |   |   estimate_image_hierarchical: Estimating image for basis vector -1 ...
# 02:07 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:07 |   |   ResidualReductor: Projecting residual operator ...
# 02:07 greedy: Estimating errors ...
# 02:07 greedy: Maximum error after 0 extensions: 4.1572846300087845 (mu = [ 1.57079633  3.14159265])
# 02:07 greedy: Computing solution snapshot for mu = [ 1.57079633  3.14159265] ...
# 02:07 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.5707963267948966, 3.141592653589793]} ...
# 02:07 greedy: Extending basis with solution snapshot ...
#
# 02:07 greedy: Reducing ...
# 02:07 |   CoerciveRBReductor: RB projection ...
# 02:07 |   CoerciveRBReductor: Assembling error estimator ...
# 02:07 |   |   ResidualReductor: Estimating residual range ...
# 02:07 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 0 ...
# 02:08 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:08 |   |   |   |   gram_schmidt: Orthonormalizing vector 1 again
# 02:08 |   |   |   |   gram_schmidt: Orthonormalizing vector 2 again
# 02:08 |   |   ResidualReductor: Projecting residual operator ...
# 02:08 greedy: Estimating errors ...
# 02:08 greedy: Maximum error after 1 extensions: 0.8662571217925156 (mu = [ 0.          1.57079633])
# 02:08 greedy: Computing solution snapshot for mu = [ 0.          1.57079633] ...
# 02:08 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [0.0, 1.5707963267948966]} ...
# 02:08 greedy: Extending basis with solution snapshot ...
#
# 02:08 greedy: Reducing ...
# 02:08 |   CoerciveRBReductor: RB projection ...
# 02:08 |   CoerciveRBReductor: Assembling error estimator ...
# 02:08 |   |   ResidualReductor: Estimating residual range ...
# 02:08 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 1 ...
# 02:08 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:08 |   |   |   |   gram_schmidt: Orthonormalizing vector 4 again
# 02:08 |   |   ResidualReductor: Projecting residual operator ...
# 02:08 greedy: Estimating errors ...
# 02:08 greedy: Maximum error after 2 extensions: 0.08632552896081801 (mu = [ 1.57079633  1.83259571])
# 02:08 greedy: Computing solution snapshot for mu = [ 1.57079633  1.83259571] ...
# 02:08 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.5707963267948966, 1.832595714594046]} ...
# 02:08 greedy: Extending basis with solution snapshot ...
# 02:08 |   gram_schmidt: Orthonormalizing vector 2 again
#
# 02:08 greedy: Reducing ...
# 02:08 |   CoerciveRBReductor: RB projection ...
# 02:08 |   CoerciveRBReductor: Assembling error estimator ...
# 02:08 |   |   ResidualReductor: Estimating residual range ...
# 02:08 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 2 ...
# 02:09 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:09 |   |   |   |   gram_schmidt: Orthonormalizing vector 6 again
# 02:09 |   |   ResidualReductor: Projecting residual operator ...
# 02:09 greedy: Estimating errors ...
# 02:09 greedy: Maximum error after 3 extensions: 0.008325101555241871 (mu = [ 1.70169602  2.74889357])
# 02:09 greedy: Computing solution snapshot for mu = [ 1.70169602  2.74889357] ...
# 02:09 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.7016960206944711, 2.748893571891069]} ...
# 02:09 greedy: Extending basis with solution snapshot ...
# 02:09 |   gram_schmidt: Orthonormalizing vector 3 again
#
# 02:09 greedy: Reducing ...
# 02:09 |   CoerciveRBReductor: RB projection ...
# 02:09 |   CoerciveRBReductor: Assembling error estimator ...
# 02:09 |   |   ResidualReductor: Estimating residual range ...
# 02:09 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 3 ...
# 02:09 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:09 |   |   |   |   gram_schmidt: Orthonormalizing vector 8 again
# 02:09 |   |   ResidualReductor: Projecting residual operator ...
# 02:09 greedy: Estimating errors ...
# 02:09 greedy: Maximum error after 4 extensions: 0.002264561059332336 (mu = [ 0.26179939  1.83259571])
# 02:09 greedy: Computing solution snapshot for mu = [ 0.26179939  1.83259571] ...
# 02:09 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [0.2617993877991494, 1.832595714594046]} ...
# 02:09 greedy: Extending basis with solution snapshot ...
# 02:09 |   gram_schmidt: Orthonormalizing vector 4 again
#
# 02:09 greedy: Reducing ...
# 02:09 |   CoerciveRBReductor: RB projection ...
# 02:09 |   CoerciveRBReductor: Assembling error estimator ...
# 02:09 |   |   ResidualReductor: Estimating residual range ...
# 02:09 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 4 ...
# 02:10 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:10 |   |   |   |   gram_schmidt: Orthonormalizing vector 10 again
# 02:10 |   |   ResidualReductor: Projecting residual operator ...
# 02:10 greedy: Estimating errors ...
# 02:10 greedy: Maximum error after 5 extensions: 8.977666189243732e-05 (mu = [ 1.43989663  3.01069296])
# 02:10 greedy: Computing solution snapshot for mu = [ 1.43989663  3.01069296] ...
# 02:10 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.4398966328953218, 3.010692959690218]} ...
# 02:10 greedy: Extending basis with solution snapshot ...
# 02:10 |   gram_schmidt: Orthonormalizing vector 5 again
#
# 02:10 greedy: Reducing ...
# 02:10 |   CoerciveRBReductor: RB projection ...
# 02:10 |   CoerciveRBReductor: Assembling error estimator ...
# 02:10 |   |   ResidualReductor: Estimating residual range ...
# 02:10 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 5 ...
# 02:10 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:10 |   |   |   |   gram_schmidt: Orthonormalizing vector 12 again
# 02:10 |   |   ResidualReductor: Projecting residual operator ...
# 02:10 greedy: Estimating errors ...
# 02:10 greedy: Maximum error after 6 extensions: 1.8876879840780046e-05 (mu = [ 0.13089969  1.43989663])
# 02:10 greedy: Computing solution snapshot for mu = [ 0.13089969  1.43989663] ...
# 02:10 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [0.1308996938995747, 1.4398966328953218]} ...
# 02:10 greedy: Extending basis with solution snapshot ...
# 02:10 |   gram_schmidt: Orthonormalizing vector 6 again
#
# 02:10 greedy: Reducing ...
# 02:10 |   CoerciveRBReductor: RB projection ...
# 02:10 |   CoerciveRBReductor: Assembling error estimator ...
# 02:10 |   |   ResidualReductor: Estimating residual range ...
# 02:10 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 6 ...
# 02:11 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:11 |   |   |   |   gram_schmidt: Orthonormalizing vector 14 again
# 02:11 |   |   ResidualReductor: Projecting residual operator ...
# 02:11 greedy: Estimating errors ...
# 02:11 greedy: Maximum error after 7 extensions: 1.924383723346276e-06 (mu = [ 1.43989663  2.35619449])
# 02:11 greedy: Computing solution snapshot for mu = [ 1.43989663  2.35619449] ...
# 02:11 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.4398966328953218, 2.356194490192345]} ...
# 02:11 greedy: Extending basis with solution snapshot ...
# 02:11 |   gram_schmidt: Orthonormalizing vector 7 again
#
# 02:11 greedy: Reducing ...
# 02:11 |   CoerciveRBReductor: RB projection ...
# 02:11 |   CoerciveRBReductor: Assembling error estimator ...
# 02:11 |   |   ResidualReductor: Estimating residual range ...
# 02:11 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 7 ...
# 02:11 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:11 |   |   |   |   gram_schmidt: Orthonormalizing vector 16 again
# 02:11 |   |   ResidualReductor: Projecting residual operator ...
# 02:11 greedy: Estimating errors ...
# 02:11 greedy: Maximum error after 8 extensions: 2.403416806897001e-07 (mu = [ 2.48709418  1.70169602])
# 02:11 greedy: Computing solution snapshot for mu = [ 2.48709418  1.70169602] ...
# 02:11 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [2.4870941840919194, 1.7016960206944711]} ...
# 02:11 greedy: Extending basis with solution snapshot ...
# 02:11 |   gram_schmidt: Orthonormalizing vector 8 again
#
# 02:11 greedy: Reducing ...
# 02:11 |   CoerciveRBReductor: RB projection ...
# 02:11 |   CoerciveRBReductor: Assembling error estimator ...
# 02:11 |   |   ResidualReductor: Estimating residual range ...
# 02:11 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 8 ...
# 02:12 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:12 |   |   |   |   gram_schmidt: Orthonormalizing vector 18 again
# 02:12 |   |   ResidualReductor: Projecting residual operator ...
# 02:12 greedy: Estimating errors ...
# 02:12 greedy: Maximum error after 9 extensions: 8.452861028117783e-09 (mu = [ 1.17809725  3.14159265])
# 02:12 greedy: Computing solution snapshot for mu = [ 1.17809725  3.14159265] ...
# 02:12 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.1780972450961724, 3.141592653589793]} ...
# 02:12 greedy: Extending basis with solution snapshot ...
# 02:12 |   gram_schmidt: Orthonormalizing vector 9 again
#
# 02:12 greedy: Reducing ...
# 02:12 |   CoerciveRBReductor: RB projection ...
# 02:12 |   CoerciveRBReductor: Assembling error estimator ...
# 02:12 |   |   ResidualReductor: Estimating residual range ...
# 02:12 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 9 ...
# 02:12 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:12 |   |   |   |   gram_schmidt: Orthonormalizing vector 20 again
# 02:12 |   |   ResidualReductor: Projecting residual operator ...
# 02:12 greedy: Estimating errors ...
# 02:12 greedy: Maximum error after 10 extensions: 2.5446068483233564e-09 (mu = [ 3.14159265  1.04719755])
# 02:12 greedy: Computing solution snapshot for mu = [ 3.14159265  1.04719755] ...
# 02:12 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [3.141592653589793, 1.0471975511965976]} ...
# 02:13 greedy: Extending basis with solution snapshot ...
# 02:13 |   gram_schmidt: Orthonormalizing vector 10 again
#
# 02:13 greedy: Reducing ...
# 02:13 |   CoerciveRBReductor: RB projection ...
# 02:13 |   CoerciveRBReductor: Assembling error estimator ...
# 02:13 |   |   ResidualReductor: Estimating residual range ...
# 02:13 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 10 ...
# 02:13 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:13 |   |   |   |   gram_schmidt: Orthonormalizing vector 22 again
# 02:13 |   |   ResidualReductor: Projecting residual operator ...
# 02:13 greedy: Estimating errors ...
# 02:13 greedy: Maximum error after 11 extensions: 1.424293744687651e-10 (mu = [ 1.43989663  1.43989663])
# 02:13 greedy: Computing solution snapshot for mu = [ 1.43989663  1.43989663] ...
# 02:13 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.4398966328953218, 1.4398966328953218]} ...
# 02:13 greedy: Extending basis with solution snapshot ...
# 02:13 |   gram_schmidt: Orthonormalizing vector 11 again
#
# 02:13 greedy: Reducing ...
# 02:13 |   CoerciveRBReductor: RB projection ...
# 02:13 |   CoerciveRBReductor: Assembling error estimator ...
# 02:13 |   |   ResidualReductor: Estimating residual range ...
# 02:13 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 11 ...
# 02:13 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:13 |   |   ResidualReductor: Projecting residual operator ...
# 02:13 greedy: Estimating errors ...
# 02:14 greedy: Maximum error after 12 extensions: 6.676493163984916e-11 (mu = [ 1.57079633  2.61799388])
# 02:14 greedy: Computing solution snapshot for mu = [ 1.57079633  2.61799388] ...
# 02:14 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.5707963267948966, 2.617993877991494]} ...
# 02:14 greedy: Extending basis with solution snapshot ...
# 02:14 |   gram_schmidt: Orthonormalizing vector 12 again
#
# 02:14 greedy: Reducing ...
# 02:14 |   CoerciveRBReductor: RB projection ...
# 02:14 |   CoerciveRBReductor: Assembling error estimator ...
# 02:14 |   |   ResidualReductor: Estimating residual range ...
# 02:14 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 12 ...
# 02:14 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:14 |   |   ResidualReductor: Projecting residual operator ...
# 02:14 greedy: Estimating errors ...
# 02:14 greedy: Maximum error after 13 extensions: 4.169832216466345e-11 (mu = [ 1.17809725  2.61799388])
# 02:14 greedy: Computing solution snapshot for mu = [ 1.17809725  2.61799388] ...
# 02:14 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.1780972450961724, 2.617993877991494]} ...
# 02:14 greedy: Extending basis with solution snapshot ...
# 02:14 |   gram_schmidt: Orthonormalizing vector 13 again
#
# 02:14 greedy: Reducing ...
# 02:14 |   CoerciveRBReductor: RB projection ...
# 02:14 |   CoerciveRBReductor: Assembling error estimator ...
# 02:14 |   |   ResidualReductor: Estimating residual range ...
# 02:14 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 13 ...
# 02:14 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:14 |   |   ResidualReductor: Projecting residual operator ...
# 02:14 greedy: Estimating errors ...
# 02:15 greedy: Maximum error after 14 extensions: 4.076148258254188e-11 (mu = [ 1.30899694  2.2252948 ])
# 02:15 greedy: Computing solution snapshot for mu = [ 1.30899694  2.2252948 ] ...
# 02:15 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.308996938995747, 2.22529479629277]} ...
# 02:15 greedy: Extending basis with solution snapshot ...
# 02:15 |   gram_schmidt: Orthonormalizing vector 14 again
#
# 02:15 greedy: Reducing ...
# 02:15 |   CoerciveRBReductor: RB projection ...
# 02:15 |   CoerciveRBReductor: Assembling error estimator ...
# 02:15 |   |   ResidualReductor: Estimating residual range ...
# 02:15 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 14 ...
# 02:15 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:15 |   |   ResidualReductor: Projecting residual operator ...
# 02:15 greedy: Estimating errors ...
# 02:15 greedy: Maximum error after 15 extensions: 3.2390929490712656e-11 (mu = [ 1.96349541  2.87979327])
# 02:15 greedy: Computing solution snapshot for mu = [ 1.96349541  2.87979327] ...
# 02:15 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.9634954084936205, 2.8797932657906435]} ...
# 02:15 greedy: Extending basis with solution snapshot ...
# 02:15 |   gram_schmidt: Orthonormalizing vector 15 again
#
# 02:15 greedy: Reducing ...
# 02:15 |   CoerciveRBReductor: RB projection ...
# 02:15 |   CoerciveRBReductor: Assembling error estimator ...
# 02:15 |   |   ResidualReductor: Estimating residual range ...
# 02:15 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 15 ...
# 02:16 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:16 |   |   ResidualReductor: Projecting residual operator ...
# 02:16 greedy: Estimating errors ...
# 02:16 greedy: Maximum error after 16 extensions: 2.6968572809468793e-11 (mu = [ 2.61799388  1.70169602])
# 02:16 greedy: Computing solution snapshot for mu = [ 2.61799388  1.70169602] ...
# 02:16 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [2.617993877991494, 1.7016960206944711]} ...
# 02:16 greedy: Extending basis with solution snapshot ...
# 02:16 |   gram_schmidt: Orthonormalizing vector 16 again
#
# 02:16 greedy: Reducing ...
# 02:16 |   CoerciveRBReductor: RB projection ...
# 02:16 |   CoerciveRBReductor: Assembling error estimator ...
# 02:16 |   |   ResidualReductor: Estimating residual range ...
# 02:16 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 16 ...
# 02:16 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:16 |   |   ResidualReductor: Projecting residual operator ...
# 02:16 greedy: Estimating errors ...
# 02:16 greedy: Maximum error after 17 extensions: 2.0314671704535277e-11 (mu = [ 1.30899694  1.96349541])
# 02:16 greedy: Computing solution snapshot for mu = [ 1.30899694  1.96349541] ...
# 02:16 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.308996938995747, 1.9634954084936205]} ...
# 02:17 greedy: Extending basis with solution snapshot ...
# 02:17 |   gram_schmidt: Orthonormalizing vector 17 again
#
# 02:17 greedy: Reducing ...
# 02:17 |   CoerciveRBReductor: RB projection ...
# 02:17 |   CoerciveRBReductor: Assembling error estimator ...
# 02:17 |   |   ResidualReductor: Estimating residual range ...
# 02:17 |   |   |   estimate_image_hierarchical: Estimating image for basis vector 17 ...
# 02:17 |   |   |   estimate_image_hierarchical: Orthonormalizing ...
# 02:17 |   |   ResidualReductor: Projecting residual operator ...
# 02:17 greedy: Estimating errors ...
# 02:17 greedy: Maximum error after 18 extensions: 1.774240758659146e-11 (mu = [ 1.57079633  3.14159265])
# 02:17 greedy: Computing solution snapshot for mu = [ 1.57079633  3.14159265] ...
# 02:17 |   StationaryDiscretization: Solving SWIPDG for {diffusion: [1.5707963267948966, 3.141592653589793]} ...
# 02:17 greedy: Extending basis with solution snapshot ...
# 02:17 |   gram_schmidt: Removing linear dependent vector 18
# 02:17 |   greedy: Extension failed. Stopping now.
# 02:17 greedy: Greedy search took 10.298464059829712 seconds
# 02:17 notebook: RB system is of size 18x18
# 02:17 notebook: maximum estimated model reduction error over training set: 1.774240758659146e-11
#
# 02:17 notebook: ... done

# %%
RB_rd = RB_greedy_data['reduced_discretization']
RB_rd.disable_logging()

plt.plot(list(range(num_RB_greedy_extensions)) + [len(range(num_RB_greedy_extensions))],
         RB_greedy_errors,
         '-o')
plt.xticks(np.arange(0, num_RB_greedy_extensions + 1, 3))
plt.yscale('log')
plt.title('error decay during greedy basis extension over training set\n({} equally distributed parameters)'.format(len(training_set)))
plt.xlabel('greedy extension step / size of the reduced basis')
plt.ylabel('max estimted relative error over training set')

# %% [markdown]
# Lets see which parameters the Greedy selected w.r.t. the reference quantity of interest (which he did not know).

# %%
logger.info('plotting parameter values selected during the greedy ...')

#reference_plot = plot_3d_surface(reference_quantity_of_interest, XX, YY)

fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, f_of_x = compute_value_matrix(RB_quantity_of_interest, XX, YY)
ax.plot_surface(x, y, f_of_x, cmap='Purples', linewidth=0, antialiased=False, alpha=0.5)
ax.view_init(elev=57.7597402597, azim=-59.6370967742)
ax.set_xlim3d([-0.10457963, 3.2961723])
ax.set_ylim3d([-0.10457963, 3.29617229])
ax.set_zlim3d([0.21921607, 4.42022848])

for mu in RB_greedy_mus:
    addplot_xy_point_as_bar(ax, mu[0], mu[1])

logger.info('... done')
# Out:
# 03:37:07 notebook: plotting parameter values selected during the greedy ...
# 03:37:07 notebook: ... done

# %% [markdown]
# _Unfortunately_, the Greedy is clever enough to detect a symmetry in the parameterization.
# Thus, it does "too much work", but not in the whole parameter domain.

# %% [markdown]
# Let us first validate that we did not destroy the quantity of interest by only using an error estimate on the solution.

# %%
def RB_quantity_of_interest(mu):
    return RB_rd.rhs.apply(RB_rd.solve(mu)).data[0]

logger.info('plotting ...')
plot_3d_surface((reference_quantity_of_interest, RB_quantity_of_interest), XX, YY)
logger.info('... done')

logger.info('computing some RB quantities of interest ...')
RB_quantities_of_interest = [RB_quantity_of_interest(mu) for mu in training_set]
logger.info('... done')

logger.info('relative L-infty error of QoI over training set: {}'.format(
    (np.max(np.abs(np.array(reference_quantities_of_interest) - np.array(RB_quantities_of_interest)))
     / np.max(reference_quantities_of_interest))
))
# Out:
# 02:25 notebook: plotting ...
# 02:32 notebook: ... done
# 02:32 notebook: computing some RB quantities of interest ...
# 02:32 notebook: ... done
# 02:32 notebook: relative L-infty error of QoI over training set: 5.602293042413464e-12

# %% [markdown]
# Visually, the surfaces are indistinguishable (the RB one should be orange), but also the L-infinity error looks good.

# %% [markdown]
# # minimizing using the standard RB discretization

# %%
logger.info('minimizing reduced quantity of interest:')

RB_minimization_data = {'num_evals': 0,
                        'evaluations' : [],
                        'evaluation_points': []}

result = minimize(partial(record_results, RB_quantity_of_interest, RB_minimization_data),
                  initial_guess,
                  method='L-BFGS-B', jac=False,
                  bounds=(parameter_range, parameter_range),
                  options={'ftol': 1e-15})

report(result, RB_minimization_data)
# Out:
# 02:32 notebook: minimizing reduced quantity of interest:
# 02:32 notebook:  succeded!
# 02:32 notebook:   mu_min:    {diffusion: [1.5707964033432422, 3.141592653589793]}
# 02:32 notebook:   QoI(mu_min): 1.2440146064383069
# 02:32 notebook:   num iterations:     6
# 02:32 notebook:   num function calls: 21
# .....................

# %%
logger.info('plotting chosen points during minimization of RB quantity of interest ...')

RB_plot = plot_3d_surface(RB_quantity_of_interest,XX, YY)

for mu in RB_minimization_data['evaluation_points']:
    addplot_xy_point_as_bar(RB_plot, mu[0], mu[1])

logger.info('... done')
# Out:
# 02:32 notebook: plotting chosen points during minimization of RB quantity of interest ...
# 02:32 notebook: ... done

# %% [markdown]
# As a comparison: chosen points during the minimization of the
# * reference QoI (green)
# * RB QoI (orange, the same as above)
# w.r.t. the reference QoI surface

# %%
logger.info('plotting ...')

reference_plot = plot_3d_surface(reference_quantity_of_interest, XX, YY)
reference_plot_mean_z_lim = 0.5*(reference_plot.get_zlim()[0] + reference_plot.get_zlim()[1])

for mu in reference_minimization_data['evaluation_points']:
    addplot_xy_point_as_bar(reference_plot, mu[0], mu[1], color='green',
                            z_range=(reference_plot.get_zlim()[0], reference_plot_mean_z_lim))

for mu in RB_minimization_data['evaluation_points']:
    addplot_xy_point_as_bar(reference_plot, mu[0], mu[1], color='orange',
                           z_range=(reference_plot_mean_z_lim, reference_plot.get_zlim()[1]))

logger.info('... done')
# Out:
# 02:32 notebook: plotting ...
# 02:39 notebook: ... done

# %% [markdown]
# As we can see, the same points are picked by the optimizers.

# %%
RB_minimizer = result.x
RB_minimum = result.fun

logger.info('relative RB l-2 minimizer error: {}'.format(
    (np.linalg.norm(reference_minimizer - RB_minimizer)/np.linalg.norm(reference_minimizer))))
logger.info('relative RB l-infty QoI error:   {}'.format(
    (np.abs(reference_minimum - RB_minimum)/np.abs(reference_minimum))[0]))
logger.info('')

extended_report(RB_minimization_data)
# Out:
# 02:39 notebook: relative RB l-2 minimizer error: 4.534160933235255e-05
# 02:39 notebook: relative RB l-infty QoI error:   9.013098529270765e-09
#
# 02:40 notebook: num_evals
# 02:40 notebook:   21
#
# 02:40 notebook: evaluations
# 02:40 notebook:   3.971612309293253
# 02:40 notebook:   3.9716122944528855
# 02:40 notebook:   3.971612300475223
# 02:40 notebook:   2.0202958506199944
# 02:40 notebook:   2.0202958523594345
# 02:40 notebook:   2.020295842875963
# 02:40 notebook:   1.5067762299080305
# 02:40 notebook:   1.5067762334433414
# 02:40 notebook:   1.506776226287868
# 02:40 notebook:   1.2482678512959713
# 02:40 notebook:   1.2482678521662014
# 02:40 notebook:   1.2482678489499026
# 02:40 notebook:   1.2444291253137756
# 02:40 notebook:   1.2444291255844726
# 02:40 notebook:   1.2444291229710593
# 02:40 notebook:   1.2440146264374758
# 02:40 notebook:   1.2440146264393557
# 02:40 notebook:   1.2440146240951224
# 02:40 notebook:   1.2440146064383069
# 02:40 notebook:   1.2440146064383073
# 02:40 notebook:   1.2440146040959534
#
# 02:40 notebook: evaluation_points
# 02:40 notebook:   [0.25, 0.5]
# 02:40 notebook:   [0.25000000999999999, 0.5]
# 02:40 notebook:   [0.25, 0.50000001000000005]
# 02:40 notebook:   [1.7340367601465232, 1.3818030305945967]
# 02:40 notebook:   [1.7340367701465231, 1.3818030305945967]
# 02:40 notebook:   [1.7340367601465232, 1.3818030405945967]
# 02:40 notebook:   [1.9216106128483426, 2.4408156740313216]
# 02:40 notebook:   [1.9216106228483425, 2.4408156740313216]
# 02:40 notebook:   [1.9216106128483426, 2.4408156840313215]
# 02:40 notebook:   [1.6688063840158089, 3.1415926535897931]
# 02:40 notebook:   [1.6688063940158089, 3.1415926535897931]
# 02:40 notebook:   [1.6688063840158089, 3.1415926635897931]
# 02:40 notebook:   [1.6014303134460843, 3.1415926535897931]
# 02:40 notebook:   [1.6014303234460843, 3.1415926535897931]
# 02:40 notebook:   [1.6014303134460843, 3.1415926635897931]
# 02:40 notebook:   [1.571009137608564, 3.1415926535897931]
# 02:40 notebook:   [1.5710091476085639, 3.1415926535897931]
# 02:40 notebook:   [1.571009137608564, 3.1415926635897931]
# 02:40 notebook:   [1.5707964033432422, 3.1415926535897931]
# 02:40 notebook:   [1.5707964133432422, 3.1415926535897931]
# 02:40 notebook:   [1.5707964033432422, 3.1415926635897931]

# %% [markdown]
# To conclude: using a standard RB Greedy, we require
# * 18 global SWIPDG evaluations (to build the RB)
# Thus
# * we need 11 global SWIPDG solves more than the reference discretization, if we only compare to the 7 evaluations required by the minimizer (without the FD approximation for the gradients)
# * but we save $39 - 18 = 21$ evaluations of the global SWIPDG model, since the finite difference approximation of the gradient are now performed using the RB

# %% [markdown]
# # setting up the LRBMS discretization

# %%
from lrbms import LRBMSReductor

LRBMS_reductor = LRBMSReductor(block_SWIPDG_disc,
                               products=[block_SWIPDG_disc.operators['local_energy_dg_product_{}'.format(ii)]
                                         for ii in range(block_space.num_blocks)],
                              order=0)

logger.info('... done')
# Out:
# 02:40 LRBMSReductor: initializing local reduced bases with DG shape functions of up to order 0 ...
# 02:40 notebook: ... done

# %%
with logger.block('reducing ...') as _:
    tt = time.time()

    LRBMS_rd = LRBMS_reductor.reduce()

logger.info('took {}s, initial reduced (LRBMS) system is of size {}x{}'.format(
    time.time() - tt,
    LRBMS_rd.solution_space.dim, LRBMS_rd.solution_space.dim))

LRBMS_reductor.disable_logging()
LRBMS_rd.disable_logging()
# Out:
# 02:40 notebook: reducing ...
# 02:40 |   LRBMSReductor: Computing oswald interpolations ...
# 02:41 |   LRBMSReductor: Computing flux reconstructions ...
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_0: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_1: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_2: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_3: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_4: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_5: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_6: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_7: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_8: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_9: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_10: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_11: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_12: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_13: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_14: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_15: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_16: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_17: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_18: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_19: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_20: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_21: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_22: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_23: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_24: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_25: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_26: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_27: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_28: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_29: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_30: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_31: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_32: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_33: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_34: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_35: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_36: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_37: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_38: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_39: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_40: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_41: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_42: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_43: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_44: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_45: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_46: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_47: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_48: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_49: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_50: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_51: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_52: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_53: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_54: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_55: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_56: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_57: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_58: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_59: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_60: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_61: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_62: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting local_energy_dg_product_63: R^96 --> R^96  (parameter type: None, class: DuneXTMatrixOperator)
# 02:42 |   LRBMSReductor: Projecting nonconformity_0: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:43 |   LRBMSReductor: Projecting residual_functional_0: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:43 |   LRBMSReductor: Projecting residual_0: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:43 |   LRBMSReductor: Projecting diffusive_flux_aa_0: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:43 |   LRBMSReductor: Projecting diffusive_flux_bb_0: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:44 |   LRBMSReductor: Projecting diffusive_flux_ab_0: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:44 |   LRBMSReductor: Projecting nonconformity_1: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:44 |   LRBMSReductor: Projecting residual_functional_1: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:44 |   LRBMSReductor: Projecting residual_1: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:44 |   LRBMSReductor: Projecting diffusive_flux_aa_1: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:45 |   LRBMSReductor: Projecting diffusive_flux_bb_1: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:45 |   LRBMSReductor: Projecting diffusive_flux_ab_1: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:45 |   LRBMSReductor: Projecting nonconformity_2: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:45 |   LRBMSReductor: Projecting residual_functional_2: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:45 |   LRBMSReductor: Projecting residual_2: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:46 |   LRBMSReductor: Projecting diffusive_flux_aa_2: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:46 |   LRBMSReductor: Projecting diffusive_flux_bb_2: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:46 |   LRBMSReductor: Projecting diffusive_flux_ab_2: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:47 |   LRBMSReductor: Projecting nonconformity_3: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:47 |   LRBMSReductor: Projecting residual_functional_3: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:47 |   LRBMSReductor: Projecting residual_3: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:47 |   LRBMSReductor: Projecting diffusive_flux_aa_3: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:47 |   LRBMSReductor: Projecting diffusive_flux_bb_3: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:48 |   LRBMSReductor: Projecting diffusive_flux_ab_3: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:48 |   LRBMSReductor: Projecting nonconformity_4: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:48 |   LRBMSReductor: Projecting residual_functional_4: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:48 |   LRBMSReductor: Projecting residual_4: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:48 |   LRBMSReductor: Projecting diffusive_flux_aa_4: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:49 |   LRBMSReductor: Projecting diffusive_flux_bb_4: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:49 |   LRBMSReductor: Projecting diffusive_flux_ab_4: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:49 |   LRBMSReductor: Projecting nonconformity_5: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:49 |   LRBMSReductor: Projecting residual_functional_5: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:49 |   LRBMSReductor: Projecting residual_5: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:50 |   LRBMSReductor: Projecting diffusive_flux_aa_5: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:50 |   LRBMSReductor: Projecting diffusive_flux_bb_5: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:50 |   LRBMSReductor: Projecting diffusive_flux_ab_5: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:51 |   LRBMSReductor: Projecting nonconformity_6: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:51 |   LRBMSReductor: Projecting residual_functional_6: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:51 |   LRBMSReductor: Projecting residual_6: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:51 |   LRBMSReductor: Projecting diffusive_flux_aa_6: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:51 |   LRBMSReductor: Projecting diffusive_flux_bb_6: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:52 |   LRBMSReductor: Projecting diffusive_flux_ab_6: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:52 |   LRBMSReductor: Projecting nonconformity_7: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:52 |   LRBMSReductor: Projecting residual_functional_7: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:52 |   LRBMSReductor: Projecting residual_7: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:52 |   LRBMSReductor: Projecting diffusive_flux_aa_7: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:53 |   LRBMSReductor: Projecting diffusive_flux_bb_7: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:53 |   LRBMSReductor: Projecting diffusive_flux_ab_7: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:54 |   LRBMSReductor: Projecting nonconformity_8: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:54 |   LRBMSReductor: Projecting residual_functional_8: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:54 |   LRBMSReductor: Projecting residual_8: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:54 |   LRBMSReductor: Projecting diffusive_flux_aa_8: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:55 |   LRBMSReductor: Projecting diffusive_flux_bb_8: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:55 |   LRBMSReductor: Projecting diffusive_flux_ab_8: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:55 |   LRBMSReductor: Projecting nonconformity_9: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:55 |   LRBMSReductor: Projecting residual_functional_9: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:55 |   LRBMSReductor: Projecting residual_9: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:55 |   LRBMSReductor: Projecting diffusive_flux_aa_9: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:56 |   LRBMSReductor: Projecting diffusive_flux_bb_9: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:56 |   LRBMSReductor: Projecting diffusive_flux_ab_9: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:56 |   LRBMSReductor: Projecting nonconformity_10: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:57 |   LRBMSReductor: Projecting residual_functional_10: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:57 |   LRBMSReductor: Projecting residual_10: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:57 |   LRBMSReductor: Projecting diffusive_flux_aa_10: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:57 |   LRBMSReductor: Projecting diffusive_flux_bb_10: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:57 |   LRBMSReductor: Projecting diffusive_flux_ab_10: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:58 |   LRBMSReductor: Projecting nonconformity_11: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:58 |   LRBMSReductor: Projecting residual_functional_11: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:58 |   LRBMSReductor: Projecting residual_11: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:58 |   LRBMSReductor: Projecting diffusive_flux_aa_11: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 02:59 |   LRBMSReductor: Projecting diffusive_flux_bb_11: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:59 |   LRBMSReductor: Projecting diffusive_flux_ab_11: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 02:59 |   LRBMSReductor: Projecting nonconformity_12: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 02:59 |   LRBMSReductor: Projecting residual_functional_12: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 02:59 |   LRBMSReductor: Projecting residual_12: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 02:59 |   LRBMSReductor: Projecting diffusive_flux_aa_12: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:00 |   LRBMSReductor: Projecting diffusive_flux_bb_12: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:00 |   LRBMSReductor: Projecting diffusive_flux_ab_12: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:00 |   LRBMSReductor: Projecting nonconformity_13: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:01 |   LRBMSReductor: Projecting residual_functional_13: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:01 |   LRBMSReductor: Projecting residual_13: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:01 |   LRBMSReductor: Projecting diffusive_flux_aa_13: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:01 |   LRBMSReductor: Projecting diffusive_flux_bb_13: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:01 |   LRBMSReductor: Projecting diffusive_flux_ab_13: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:02 |   LRBMSReductor: Projecting nonconformity_14: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:02 |   LRBMSReductor: Projecting residual_functional_14: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:02 |   LRBMSReductor: Projecting residual_14: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:02 |   LRBMSReductor: Projecting diffusive_flux_aa_14: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:03 |   LRBMSReductor: Projecting diffusive_flux_bb_14: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:03 |   LRBMSReductor: Projecting diffusive_flux_ab_14: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:03 |   LRBMSReductor: Projecting nonconformity_15: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:03 |   LRBMSReductor: Projecting residual_functional_15: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:03 |   LRBMSReductor: Projecting residual_15: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:03 |   LRBMSReductor: Projecting diffusive_flux_aa_15: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:04 |   LRBMSReductor: Projecting diffusive_flux_bb_15: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:04 |   LRBMSReductor: Projecting diffusive_flux_ab_15: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:04 |   LRBMSReductor: Projecting nonconformity_16: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:05 |   LRBMSReductor: Projecting residual_functional_16: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:05 |   LRBMSReductor: Projecting residual_16: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:05 |   LRBMSReductor: Projecting diffusive_flux_aa_16: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:05 |   LRBMSReductor: Projecting diffusive_flux_bb_16: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:05 |   LRBMSReductor: Projecting diffusive_flux_ab_16: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:06 |   LRBMSReductor: Projecting nonconformity_17: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:06 |   LRBMSReductor: Projecting residual_functional_17: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:06 |   LRBMSReductor: Projecting residual_17: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:06 |   LRBMSReductor: Projecting diffusive_flux_aa_17: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:07 |   LRBMSReductor: Projecting diffusive_flux_bb_17: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:07 |   LRBMSReductor: Projecting diffusive_flux_ab_17: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:08 |   LRBMSReductor: Projecting nonconformity_18: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:08 |   LRBMSReductor: Projecting residual_functional_18: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:08 |   LRBMSReductor: Projecting residual_18: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:08 |   LRBMSReductor: Projecting diffusive_flux_aa_18: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:09 |   LRBMSReductor: Projecting diffusive_flux_bb_18: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:09 |   LRBMSReductor: Projecting diffusive_flux_ab_18: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:09 |   LRBMSReductor: Projecting nonconformity_19: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:09 |   LRBMSReductor: Projecting residual_functional_19: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:09 |   LRBMSReductor: Projecting residual_19: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:09 |   LRBMSReductor: Projecting diffusive_flux_aa_19: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:10 |   LRBMSReductor: Projecting diffusive_flux_bb_19: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:10 |   LRBMSReductor: Projecting diffusive_flux_ab_19: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:10 |   LRBMSReductor: Projecting nonconformity_20: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:11 |   LRBMSReductor: Projecting residual_functional_20: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:11 |   LRBMSReductor: Projecting residual_20: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:11 |   LRBMSReductor: Projecting diffusive_flux_aa_20: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:11 |   LRBMSReductor: Projecting diffusive_flux_bb_20: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:11 |   LRBMSReductor: Projecting diffusive_flux_ab_20: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:12 |   LRBMSReductor: Projecting nonconformity_21: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:12 |   LRBMSReductor: Projecting residual_functional_21: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:12 |   LRBMSReductor: Projecting residual_21: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:12 |   LRBMSReductor: Projecting diffusive_flux_aa_21: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:13 |   LRBMSReductor: Projecting diffusive_flux_bb_21: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:13 |   LRBMSReductor: Projecting diffusive_flux_ab_21: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:13 |   LRBMSReductor: Projecting nonconformity_22: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:13 |   LRBMSReductor: Projecting residual_functional_22: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:13 |   LRBMSReductor: Projecting residual_22: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:13 |   LRBMSReductor: Projecting diffusive_flux_aa_22: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:14 |   LRBMSReductor: Projecting diffusive_flux_bb_22: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:14 |   LRBMSReductor: Projecting diffusive_flux_ab_22: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:14 |   LRBMSReductor: Projecting nonconformity_23: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:15 |   LRBMSReductor: Projecting residual_functional_23: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:15 |   LRBMSReductor: Projecting residual_23: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:15 |   LRBMSReductor: Projecting diffusive_flux_aa_23: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:15 |   LRBMSReductor: Projecting diffusive_flux_bb_23: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:16 |   LRBMSReductor: Projecting diffusive_flux_ab_23: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:16 |   LRBMSReductor: Projecting nonconformity_24: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:16 |   LRBMSReductor: Projecting residual_functional_24: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:16 |   LRBMSReductor: Projecting residual_24: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:16 |   LRBMSReductor: Projecting diffusive_flux_aa_24: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:17 |   LRBMSReductor: Projecting diffusive_flux_bb_24: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:17 |   LRBMSReductor: Projecting diffusive_flux_ab_24: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:17 |   LRBMSReductor: Projecting nonconformity_25: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:17 |   LRBMSReductor: Projecting residual_functional_25: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:17 |   LRBMSReductor: Projecting residual_25: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:17 |   LRBMSReductor: Projecting diffusive_flux_aa_25: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:18 |   LRBMSReductor: Projecting diffusive_flux_bb_25: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:18 |   LRBMSReductor: Projecting diffusive_flux_ab_25: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:19 |   LRBMSReductor: Projecting nonconformity_26: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:19 |   LRBMSReductor: Projecting residual_functional_26: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:19 |   LRBMSReductor: Projecting residual_26: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:19 |   LRBMSReductor: Projecting diffusive_flux_aa_26: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:19 |   LRBMSReductor: Projecting diffusive_flux_bb_26: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:20 |   LRBMSReductor: Projecting diffusive_flux_ab_26: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:20 |   LRBMSReductor: Projecting nonconformity_27: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:20 |   LRBMSReductor: Projecting residual_functional_27: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:20 |   LRBMSReductor: Projecting residual_27: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:20 |   LRBMSReductor: Projecting diffusive_flux_aa_27: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:21 |   LRBMSReductor: Projecting diffusive_flux_bb_27: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:21 |   LRBMSReductor: Projecting diffusive_flux_ab_27: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:21 |   LRBMSReductor: Projecting nonconformity_28: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:21 |   LRBMSReductor: Projecting residual_functional_28: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:21 |   LRBMSReductor: Projecting residual_28: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:22 |   LRBMSReductor: Projecting diffusive_flux_aa_28: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:22 |   LRBMSReductor: Projecting diffusive_flux_bb_28: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:22 |   LRBMSReductor: Projecting diffusive_flux_ab_28: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:23 |   LRBMSReductor: Projecting nonconformity_29: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:23 |   LRBMSReductor: Projecting residual_functional_29: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:23 |   LRBMSReductor: Projecting residual_29: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:23 |   LRBMSReductor: Projecting diffusive_flux_aa_29: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:24 |   LRBMSReductor: Projecting diffusive_flux_bb_29: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:24 |   LRBMSReductor: Projecting diffusive_flux_ab_29: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:24 |   LRBMSReductor: Projecting nonconformity_30: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:24 |   LRBMSReductor: Projecting residual_functional_30: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:24 |   LRBMSReductor: Projecting residual_30: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:24 |   LRBMSReductor: Projecting diffusive_flux_aa_30: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:26 |   LRBMSReductor: Projecting diffusive_flux_bb_30: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:26 |   LRBMSReductor: Projecting diffusive_flux_ab_30: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:26 |   LRBMSReductor: Projecting nonconformity_31: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:26 |   LRBMSReductor: Projecting residual_functional_31: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:26 |   LRBMSReductor: Projecting residual_31: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:27 |   LRBMSReductor: Projecting diffusive_flux_aa_31: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:27 |   LRBMSReductor: Projecting diffusive_flux_bb_31: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:27 |   LRBMSReductor: Projecting diffusive_flux_ab_31: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:27 |   LRBMSReductor: Projecting nonconformity_32: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:28 |   LRBMSReductor: Projecting residual_functional_32: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:28 |   LRBMSReductor: Projecting residual_32: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:28 |   LRBMSReductor: Projecting diffusive_flux_aa_32: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:28 |   LRBMSReductor: Projecting diffusive_flux_bb_32: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:29 |   LRBMSReductor: Projecting diffusive_flux_ab_32: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:29 |   LRBMSReductor: Projecting nonconformity_33: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:29 |   LRBMSReductor: Projecting residual_functional_33: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:29 |   LRBMSReductor: Projecting residual_33: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:29 |   LRBMSReductor: Projecting diffusive_flux_aa_33: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:30 |   LRBMSReductor: Projecting diffusive_flux_bb_33: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:30 |   LRBMSReductor: Projecting diffusive_flux_ab_33: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:30 |   LRBMSReductor: Projecting nonconformity_34: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:30 |   LRBMSReductor: Projecting residual_functional_34: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:30 |   LRBMSReductor: Projecting residual_34: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:31 |   LRBMSReductor: Projecting diffusive_flux_aa_34: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:31 |   LRBMSReductor: Projecting diffusive_flux_bb_34: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:31 |   LRBMSReductor: Projecting diffusive_flux_ab_34: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:32 |   LRBMSReductor: Projecting nonconformity_35: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:32 |   LRBMSReductor: Projecting residual_functional_35: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:32 |   LRBMSReductor: Projecting residual_35: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:32 |   LRBMSReductor: Projecting diffusive_flux_aa_35: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:32 |   LRBMSReductor: Projecting diffusive_flux_bb_35: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:33 |   LRBMSReductor: Projecting diffusive_flux_ab_35: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:33 |   LRBMSReductor: Projecting nonconformity_36: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:33 |   LRBMSReductor: Projecting residual_functional_36: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:33 |   LRBMSReductor: Projecting residual_36: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:33 |   LRBMSReductor: Projecting diffusive_flux_aa_36: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:34 |   LRBMSReductor: Projecting diffusive_flux_bb_36: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:34 |   LRBMSReductor: Projecting diffusive_flux_ab_36: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:34 |   LRBMSReductor: Projecting nonconformity_37: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:34 |   LRBMSReductor: Projecting residual_functional_37: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:34 |   LRBMSReductor: Projecting residual_37: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:35 |   LRBMSReductor: Projecting diffusive_flux_aa_37: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:35 |   LRBMSReductor: Projecting diffusive_flux_bb_37: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:35 |   LRBMSReductor: Projecting diffusive_flux_ab_37: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:36 |   LRBMSReductor: Projecting nonconformity_38: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:36 |   LRBMSReductor: Projecting residual_functional_38: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:36 |   LRBMSReductor: Projecting residual_38: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:36 |   LRBMSReductor: Projecting diffusive_flux_aa_38: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:37 |   LRBMSReductor: Projecting diffusive_flux_bb_38: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:37 |   LRBMSReductor: Projecting diffusive_flux_ab_38: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:37 |   LRBMSReductor: Projecting nonconformity_39: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:37 |   LRBMSReductor: Projecting residual_functional_39: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:37 |   LRBMSReductor: Projecting residual_39: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:37 |   LRBMSReductor: Projecting diffusive_flux_aa_39: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:38 |   LRBMSReductor: Projecting diffusive_flux_bb_39: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:38 |   LRBMSReductor: Projecting diffusive_flux_ab_39: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:38 |   LRBMSReductor: Projecting nonconformity_40: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:38 |   LRBMSReductor: Projecting residual_functional_40: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:38 |   LRBMSReductor: Projecting residual_40: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:39 |   LRBMSReductor: Projecting diffusive_flux_aa_40: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:39 |   LRBMSReductor: Projecting diffusive_flux_bb_40: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:39 |   LRBMSReductor: Projecting diffusive_flux_ab_40: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:40 |   LRBMSReductor: Projecting nonconformity_41: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:40 |   LRBMSReductor: Projecting residual_functional_41: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:40 |   LRBMSReductor: Projecting residual_41: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:40 |   LRBMSReductor: Projecting diffusive_flux_aa_41: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:41 |   LRBMSReductor: Projecting diffusive_flux_bb_41: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:41 |   LRBMSReductor: Projecting diffusive_flux_ab_41: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:41 |   LRBMSReductor: Projecting nonconformity_42: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:41 |   LRBMSReductor: Projecting residual_functional_42: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:41 |   LRBMSReductor: Projecting residual_42: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:41 |   LRBMSReductor: Projecting diffusive_flux_aa_42: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:42 |   LRBMSReductor: Projecting diffusive_flux_bb_42: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:42 |   LRBMSReductor: Projecting diffusive_flux_ab_42: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:42 |   LRBMSReductor: Projecting nonconformity_43: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:42 |   LRBMSReductor: Projecting residual_functional_43: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:43 |   LRBMSReductor: Projecting residual_43: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:43 |   LRBMSReductor: Projecting diffusive_flux_aa_43: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:43 |   LRBMSReductor: Projecting diffusive_flux_bb_43: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:43 |   LRBMSReductor: Projecting diffusive_flux_ab_43: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:44 |   LRBMSReductor: Projecting nonconformity_44: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:44 |   LRBMSReductor: Projecting residual_functional_44: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:44 |   LRBMSReductor: Projecting residual_44: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:44 |   LRBMSReductor: Projecting diffusive_flux_aa_44: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:45 |   LRBMSReductor: Projecting diffusive_flux_bb_44: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:45 |   LRBMSReductor: Projecting diffusive_flux_ab_44: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:45 |   LRBMSReductor: Projecting nonconformity_45: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:45 |   LRBMSReductor: Projecting residual_functional_45: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:45 |   LRBMSReductor: Projecting residual_45: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:45 |   LRBMSReductor: Projecting diffusive_flux_aa_45: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:46 |   LRBMSReductor: Projecting diffusive_flux_bb_45: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:46 |   LRBMSReductor: Projecting diffusive_flux_ab_45: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:46 |   LRBMSReductor: Projecting nonconformity_46: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:47 |   LRBMSReductor: Projecting residual_functional_46: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:47 |   LRBMSReductor: Projecting residual_46: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:47 |   LRBMSReductor: Projecting diffusive_flux_aa_46: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:48 |   LRBMSReductor: Projecting diffusive_flux_bb_46: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:48 |   LRBMSReductor: Projecting diffusive_flux_ab_46: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:49 |   LRBMSReductor: Projecting nonconformity_47: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:49 |   LRBMSReductor: Projecting residual_functional_47: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:49 |   LRBMSReductor: Projecting residual_47: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:49 |   LRBMSReductor: Projecting diffusive_flux_aa_47: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:50 |   LRBMSReductor: Projecting diffusive_flux_bb_47: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:50 |   LRBMSReductor: Projecting diffusive_flux_ab_47: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:50 |   LRBMSReductor: Projecting nonconformity_48: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:50 |   LRBMSReductor: Projecting residual_functional_48: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:50 |   LRBMSReductor: Projecting residual_48: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:50 |   LRBMSReductor: Projecting diffusive_flux_aa_48: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:51 |   LRBMSReductor: Projecting diffusive_flux_bb_48: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:51 |   LRBMSReductor: Projecting diffusive_flux_ab_48: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:51 |   LRBMSReductor: Projecting nonconformity_49: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:52 |   LRBMSReductor: Projecting residual_functional_49: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:52 |   LRBMSReductor: Projecting residual_49: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:52 |   LRBMSReductor: Projecting diffusive_flux_aa_49: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:52 |   LRBMSReductor: Projecting diffusive_flux_bb_49: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:52 |   LRBMSReductor: Projecting diffusive_flux_ab_49: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:53 |   LRBMSReductor: Projecting nonconformity_50: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:53 |   LRBMSReductor: Projecting residual_functional_50: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:53 |   LRBMSReductor: Projecting residual_50: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:53 |   LRBMSReductor: Projecting diffusive_flux_aa_50: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:54 |   LRBMSReductor: Projecting diffusive_flux_bb_50: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:54 |   LRBMSReductor: Projecting diffusive_flux_ab_50: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:54 |   LRBMSReductor: Projecting nonconformity_51: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:54 |   LRBMSReductor: Projecting residual_functional_51: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:54 |   LRBMSReductor: Projecting residual_51: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:54 |   LRBMSReductor: Projecting diffusive_flux_aa_51: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:55 |   LRBMSReductor: Projecting diffusive_flux_bb_51: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:55 |   LRBMSReductor: Projecting diffusive_flux_ab_51: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:55 |   LRBMSReductor: Projecting nonconformity_52: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:56 |   LRBMSReductor: Projecting residual_functional_52: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:56 |   LRBMSReductor: Projecting residual_52: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:56 |   LRBMSReductor: Projecting diffusive_flux_aa_52: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:56 |   LRBMSReductor: Projecting diffusive_flux_bb_52: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:56 |   LRBMSReductor: Projecting diffusive_flux_ab_52: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:57 |   LRBMSReductor: Projecting nonconformity_53: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:57 |   LRBMSReductor: Projecting residual_functional_53: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:57 |   LRBMSReductor: Projecting residual_53: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:57 |   LRBMSReductor: Projecting diffusive_flux_aa_53: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:58 |   LRBMSReductor: Projecting diffusive_flux_bb_53: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:58 |   LRBMSReductor: Projecting diffusive_flux_ab_53: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:58 |   LRBMSReductor: Projecting nonconformity_54: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 03:58 |   LRBMSReductor: Projecting residual_functional_54: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 03:58 |   LRBMSReductor: Projecting residual_54: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:58 |   LRBMSReductor: Projecting diffusive_flux_aa_54: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 03:59 |   LRBMSReductor: Projecting diffusive_flux_bb_54: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 03:59 |   LRBMSReductor: Projecting diffusive_flux_ab_54: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 03:59 |   LRBMSReductor: Projecting nonconformity_55: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:00 |   LRBMSReductor: Projecting residual_functional_55: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:00 |   LRBMSReductor: Projecting residual_55: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:00 |   LRBMSReductor: Projecting diffusive_flux_aa_55: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:00 |   LRBMSReductor: Projecting diffusive_flux_bb_55: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:00 |   LRBMSReductor: Projecting diffusive_flux_ab_55: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:01 |   LRBMSReductor: Projecting nonconformity_56: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:01 |   LRBMSReductor: Projecting residual_functional_56: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:01 |   LRBMSReductor: Projecting residual_56: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:01 |   LRBMSReductor: Projecting diffusive_flux_aa_56: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:02 |   LRBMSReductor: Projecting diffusive_flux_bb_56: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:02 |   LRBMSReductor: Projecting diffusive_flux_ab_56: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:02 |   LRBMSReductor: Projecting nonconformity_57: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:02 |   LRBMSReductor: Projecting residual_functional_57: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:02 |   LRBMSReductor: Projecting residual_57: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:02 |   LRBMSReductor: Projecting diffusive_flux_aa_57: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:03 |   LRBMSReductor: Projecting diffusive_flux_bb_57: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:03 |   LRBMSReductor: Projecting diffusive_flux_ab_57: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:03 |   LRBMSReductor: Projecting nonconformity_58: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:04 |   LRBMSReductor: Projecting residual_functional_58: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:04 |   LRBMSReductor: Projecting residual_58: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:04 |   LRBMSReductor: Projecting diffusive_flux_aa_58: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:04 |   LRBMSReductor: Projecting diffusive_flux_bb_58: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:05 |   LRBMSReductor: Projecting diffusive_flux_ab_58: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:05 |   LRBMSReductor: Projecting nonconformity_59: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:05 |   LRBMSReductor: Projecting residual_functional_59: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:05 |   LRBMSReductor: Projecting residual_59: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:05 |   LRBMSReductor: Projecting diffusive_flux_aa_59: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:06 |   LRBMSReductor: Projecting diffusive_flux_bb_59: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:06 |   LRBMSReductor: Projecting diffusive_flux_ab_59: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:06 |   LRBMSReductor: Projecting nonconformity_60: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:06 |   LRBMSReductor: Projecting residual_functional_60: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:06 |   LRBMSReductor: Projecting residual_60: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:06 |   LRBMSReductor: Projecting diffusive_flux_aa_60: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:07 |   LRBMSReductor: Projecting diffusive_flux_bb_60: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:07 |   LRBMSReductor: Projecting diffusive_flux_ab_60: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:07 |   LRBMSReductor: Projecting nonconformity_61: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:08 |   LRBMSReductor: Projecting residual_functional_61: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:08 |   LRBMSReductor: Projecting residual_61: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:08 |   LRBMSReductor: Projecting diffusive_flux_aa_61: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:08 |   LRBMSReductor: Projecting diffusive_flux_bb_61: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:08 |   LRBMSReductor: Projecting diffusive_flux_ab_61: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:09 |   LRBMSReductor: Projecting nonconformity_62: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:09 |   LRBMSReductor: Projecting residual_functional_62: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:09 |   LRBMSReductor: Projecting residual_62: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:09 |   LRBMSReductor: Projecting diffusive_flux_aa_62: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:10 |   LRBMSReductor: Projecting diffusive_flux_bb_62: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:10 |   LRBMSReductor: Projecting diffusive_flux_ab_62: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:10 |   LRBMSReductor: Projecting nonconformity_63: R^46464 --> R^46464  (parameter type: {}, class: BlockOperator)
# 04:10 |   LRBMSReductor: Projecting residual_functional_63: R^200704 --> R^1  (parameter type: {}, class: BlockOperator)
# 04:10 |   LRBMSReductor: Projecting residual_63: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:10 |   LRBMSReductor: Projecting diffusive_flux_aa_63: R^6144 --> R^6144  (parameter type: {}, class: LincombOperator)
# 04:11 |   LRBMSReductor: Projecting diffusive_flux_bb_63: R^200704 --> R^200704  (parameter type: {}, class: BlockOperator)
# 04:11 |   LRBMSReductor: Projecting diffusive_flux_ab_63: R^200704 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:11 |   LRBMSReductor: Projecting lhs: R^6144 --> R^6144  (parameter type: {diffusion: (2,)}, class: LincombOperator)
# 04:12 |   LRBMSReductor: Projecting VectorFunctional: R^6144 --> R^1  (parameter type: None, class: VectorFunctional)
# 06:25 notebook: took 225.67462372779846s, initial reduced (LRBMS) system is of size 64x64

# %% [markdown]
# # minimizing using the LRBMS discretization

# %% [markdown]
# ## using the (insufficient) initial zero-order basis

# %%
logger.info('plotting ...')

def LRBMS_0_quantity_of_interest(mu):
    return LRBMS_rd.rhs.apply(LRBMS_rd.solve(mu)).data[0]

plot_3d_surface((reference_quantity_of_interest, LRBMS_0_quantity_of_interest), XX, YY)

logger.info('... done')
logger.info('computing some zero order LRBMS reduced quantities of interest ...')

LRBMS_0_quantities_of_interest = [LRBMS_0_quantity_of_interest(mu) for mu in training_set]

logger.info('relative L-infty error w.r.t. reference QoI: {}'.format(
    (np.max(np.abs(np.array(reference_quantities_of_interest) - np.array(LRBMS_0_quantities_of_interest)))
     /np.max(np.abs(reference_quantities_of_interest)))
))
# Out:
# 06:25 notebook: plotting ...
# 06:33 notebook: ... done
# 06:33 notebook: computing some zero order LRBMS reduced quantities of interest ...
# 06:33 notebook: relative L-infty error w.r.t. reference QoI: 0.945021037261154

# %% [markdown]
# As we can see, the LRBMS-0-order basis QoI (bottom) is far away from the reference QoI (top), also the relative $l_\infty-l_\infty$ error is $94.5\%$.
# But we can try to minimize never-the-less:

# %%
logger.info('minimizing order-0 LRBMS quantity of interest ...')

LRBMS_0_minimization_data = {'num_evals': 0,
                             'evaluations' : [],
                             'evaluation_points': []}

result = minimize(partial(record_results, LRBMS_0_quantity_of_interest, LRBMS_0_minimization_data),
                  initial_guess,
                  method='L-BFGS-B', jac=False,
                  bounds=(parameter_range, parameter_range),
                  options={'ftol': 1e-15})

report(result, LRBMS_0_minimization_data)

LRBMS_0_minimizer = result.x
LRBMS_0_minimum = result.fun

logger.info('')
logger.info('relative LRBMS (order-0) l-2 minimizer error: {}'.format(
    (np.linalg.norm(reference_minimizer - LRBMS_0_minimizer)/np.linalg.norm(reference_minimizer))))
logger.info('relative LRBMS (order-0) l-infty QoI error:   {}'.format(
    (np.abs(reference_minimum - LRBMS_0_minimum)/np.abs(reference_minimum))[0]))
logger.info('')

extended_report(LRBMS_0_minimization_data)
# Out:
# 06:33 notebook: minimizing order-0 LRBMS quantity of interest ...
# 06:33 notebook:  succeded!
# 06:33 notebook:   mu_min:    {diffusion: [1.570633249972388, 3.141592653589793]}
# 06:33 notebook:   QoI(mu_min): 0.06650507730437835
# 06:33 notebook:   num iterations:     7
# 06:33 notebook:   num function calls: 30
#
# 06:33 notebook: relative LRBMS (order-0) l-2 minimizer error: 9.179125022757327e-05
# 06:33 notebook: relative LRBMS (order-0) l-infty QoI error:   0.9465399551092332
#
# 06:33 notebook: num_evals
# 06:33 notebook:   30
#
# 06:33 notebook: evaluations
# 06:33 notebook:   0.21921607063403353
# 06:33 notebook:   0.21921606980255703
# 06:33 notebook:   0.2192160701583435
# 06:33 notebook:   0.2098899572784674
# 06:33 notebook:   0.20988995646481745
# 06:33 notebook:   0.20988995671805546
# 06:33 notebook:   0.2000520669538418
# 06:33 notebook:   0.20005206616518
# 06:33 notebook:   0.2000520663378181
# 06:33 notebook:   0.1628067229515525
# 06:33 notebook:   0.16280672237572352
# 06:33 notebook:   0.16280672229204463
# 06:33 notebook:   0.142488269549998
# 06:33 notebook:   0.14248827170190936
# 06:33 notebook:   0.1424882694002517
# 06:33 notebook:   0.0965975069639978
# 06:33 notebook:   0.09659750696861677
# 06:33 notebook:   0.09659750663854365
# 06:33 notebook:   0.08205425807814587
# 06:33 notebook:   0.08205425817659742
# 06:33 notebook:   0.08205425785567204
# 06:33 notebook:   0.06711986935283876
# 06:33 notebook:   0.0671198694307463
# 06:33 notebook:   0.06711986920983815
# 06:33 notebook:   0.0665088479128736
# 06:33 notebook:   0.06650884790683631
# 06:33 notebook:   0.06650884777056974
# 06:33 notebook:   0.06650507730437835
# 06:33 notebook:   0.0665050773042996
# 06:33 notebook:   0.06650507716207885
#
# 06:33 notebook: evaluation_points
# 06:33 notebook:   [0.25, 0.5]
# 06:33 notebook:   [0.25000000999999999, 0.5]
# 06:33 notebook:   [0.25, 0.50000001000000005]
# 06:33 notebook:   [0.33314764987638057, 0.54756900429114808]
# 06:33 notebook:   [0.33314765987638056, 0.54756900429114808]
# 06:33 notebook:   [0.33314764987638057, 0.54756901429114813]
# 06:33 notebook:   [0.4145126451732537, 0.60361019819882245]
# 06:33 notebook:   [0.4145126551732537, 0.60361019819882245]
# 06:33 notebook:   [0.4145126451732537, 0.6036102081988225]
# 06:33 notebook:   [0.73997262636074623, 0.82777497382951992]
# 06:33 notebook:   [0.73997263636074628, 0.82777497382951992]
# 06:33 notebook:   [0.73997262636074623, 0.82777498382951997]
# 06:33 notebook:   [2.8704810444721907, 3.1415926535897931]
# 06:33 notebook:   [2.8704810544721906, 3.1415926535897931]
# 06:33 notebook:   [2.8704810444721907, 3.1415926635897931]
# 06:33 notebook:   [1.5788893729070046, 1.738872242211289]
# 06:33 notebook:   [1.5788893829070045, 1.738872242211289]
# 06:33 notebook:   [1.5788893729070046, 1.7388722522112889]
# 06:33 notebook:   [1.7524016727477649, 2.3134223467036161]
# 06:33 notebook:   [1.7524016827477649, 2.3134223467036161]
# 06:33 notebook:   [1.7524016727477649, 2.3134223567036161]
# 06:33 notebook:   [1.7297495114926191, 3.1415926535897931]
# 06:33 notebook:   [1.7297495214926191, 3.1415926535897931]
# 06:33 notebook:   [1.7297495114926191, 3.1415926635897931]
# 06:33 notebook:   [1.5583028401455976, 3.1415926535897931]
# 06:33 notebook:   [1.5583028501455976, 3.1415926535897931]
# 06:33 notebook:   [1.5583028401455976, 3.1415926635897931]
# 06:33 notebook:   [1.5706332499723881, 3.1415926535897931]
# 06:33 notebook:   [1.570633259972388, 3.1415926535897931]
# 06:33 notebook:   [1.5706332499723881, 3.1415926635897931]
# ..............................

# %% [markdown]
# While the relative error in the QoI is $94.65\%$, the minimizing parameter (arg min) is already very close (a relative $l_2$-error of $9\cdot10^{-5}$). This is due to the fact that while the LRBMS-0-order QoI surface is far away from the reference QoI surface, the shape is comparable. We can see this by plotting the LRBMS-0-order surface standalone, with rescaled axes (mind the z-axes limits when comparing to one of the plots above):

# %%
# we plot the constant function first to ensure the same colormap for the 0-order surface
plot_3d_surface((lambda mu: 0.03, LRBMS_0_quantity_of_interest), XX, YY)

# %% [markdown]
# To conclude: if we are "only" interested in the minimizing parameter, and if we had an a posteriori error estimate for detection, the online enrichment would not even start and the 0-order basis would be sufficient.
# We did not require any global SWIPDG evaluations here.

# %% [markdown]
# ## using the adaptive online enrichment

# %%
logger.info('minimizing adaptive LRBMS quantity of interest ...')
logger.info('')

LRBMS_reductor.disable_logging()

from online_enrichment import AdaptiveEnrichment

config['marking_doerfler_theta'] = 0.85
config['marking_max_age'] = 3

online_adaptive_LRBMS = AdaptiveEnrichment(grid_and_problem_data,
                                           block_SWIPDG_disc, block_space,
                                           LRBMS_reductor, LRBMS_rd,
                                           config['enrichment_target_error'],
                                           config['marking_doerfler_theta'],
                                           config['marking_max_age'])

set_log_levels({'pymor.algorithms.gram_schmidt': 'WARN'})

adaptive_LRBMS_minimization_data = {'num_evals': 0,
                                    'evaluation_points': [],
                                    'evaluations' : [],
                                    'intermediate_evaluations' : [],
                                    'intermediate_evaluation_points': [],
                                    'num_local_solves': []}


def adaptive_LRBMS_quantity_of_interest(mu):
    
    num_solves = [0]
    
    def callback(rd_, U_, mu_, data_):
        # we need to copy the data here, since the added mu is changed inplace by minimize afterwards
        adaptive_LRBMS_minimization_data['intermediate_evaluation_points'].append(
            [mu_['diffusion'][0], mu_['diffusion'][1]])
        QoI = rd_.rhs.apply(U_).data[0]
        adaptive_LRBMS_minimization_data['intermediate_evaluations'].append(QoI)
        num_solves[0] += data_['local_problem_solves']

    mu = parse_parameter(mu)
    U, rd, _ = online_adaptive_LRBMS.solve(mu, callback=callback)
    
    adaptive_LRBMS_minimization_data['num_local_solves'].append(num_solves[0])
    
    return rd.rhs.apply(U).data[0]


result = minimize(partial(record_results,
                          adaptive_LRBMS_quantity_of_interest,
                          adaptive_LRBMS_minimization_data),
                  initial_guess,
                  method='L-BFGS-B', jac=False,
                  bounds=(parameter_range, parameter_range),
                  options={'ftol': 1e-15})

logger.info('')
report(result, adaptive_LRBMS_minimization_data)
# Out:
# 06:34 notebook: minimizing adaptive LRBMS quantity of interest ...
#
# 06:34 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 06:38 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [0.25, 0.5]} is 0.1437380405501575
# 06:38 AdaptiveEnrichment: solving 64-dimensional system for mu = {diffusion: [0.25, 0.5]} ...
# 06:38 |   |INFO3|AdaptiveEnrichment: estimated error 4.378925579807537 above target error of 0.1437380405501575, enriching ...
# 06:38 |   |INFO3|AdaptiveEnrichment: marked 33/64 subdomains due to Dörfler marking
# 06:38 |   |INFO3|AdaptiveEnrichment:    and 0/31 additionally due to age marking
# 06:38 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 33 subdomains ...
# 06:39 |   |INFO3|AdaptiveEnrichment: reducing ...
# 10:25 |   |INFO3|AdaptiveEnrichment: added 33 local basis functions, system size increase: 64 --> 97
# 10:25 |   |INFO3|AdaptiveEnrichment: estimated error 7.4005555502486455 above target error of 0.1437380405501575, enriching ...
# 10:25 |   |INFO3|AdaptiveEnrichment: marked 14/64 subdomains due to Dörfler marking
# 10:25 |   |INFO3|AdaptiveEnrichment:    and 0/50 additionally due to age marking
# 10:25 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 14 subdomains ...
# 10:25 |   |INFO3|AdaptiveEnrichment: reducing ...
# 14:16 |   |INFO3|AdaptiveEnrichment: added 14 local basis functions, system size increase: 97 --> 111
# 14:16 |   |INFO3|AdaptiveEnrichment: estimated error 6.472437752475843 above target error of 0.1437380405501575, enriching ...
# 14:16 |   |INFO3|AdaptiveEnrichment: marked 12/64 subdomains due to Dörfler marking
# 14:16 |   |INFO3|AdaptiveEnrichment:    and 0/52 additionally due to age marking
# 14:16 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 12 subdomains ...
# 14:17 |   |INFO3|AdaptiveEnrichment: reducing ...
# 18:11 |   |INFO3|AdaptiveEnrichment: added 12 local basis functions, system size increase: 111 --> 123
# 18:11 |   |INFO3|AdaptiveEnrichment: estimated error 4.09349431447818 above target error of 0.1437380405501575, enriching ...
# 18:11 |   |INFO3|AdaptiveEnrichment: marked 20/64 subdomains due to Dörfler marking
# 18:11 |   |INFO3|AdaptiveEnrichment:    and 4/44 additionally due to age marking
# 18:11 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 24 subdomains ...
# 18:11 |   |INFO3|AdaptiveEnrichment: reducing ...
# 21:55 |   |INFO3|AdaptiveEnrichment: added 24 local basis functions, system size increase: 123 --> 147
# 21:55 |   |INFO3|AdaptiveEnrichment: estimated error 2.6988084326998205 above target error of 0.1437380405501575, enriching ...
# 21:55 |   |INFO3|AdaptiveEnrichment: marked 19/64 subdomains due to Dörfler marking
# 21:55 |   |INFO3|AdaptiveEnrichment:    and 15/45 additionally due to age marking
# 21:55 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 34 subdomains ...
# 21:55 |   |INFO3|AdaptiveEnrichment: reducing ...
# 25:40 |   |INFO3|AdaptiveEnrichment: added 34 local basis functions, system size increase: 147 --> 181
# 25:40 |   |INFO3|AdaptiveEnrichment: estimated error 1.3558572922313337 above target error of 0.1437380405501575, enriching ...
# 25:40 |   |INFO3|AdaptiveEnrichment: marked 17/64 subdomains due to Dörfler marking
# 25:40 |   |INFO3|AdaptiveEnrichment:    and 1/47 additionally due to age marking
# 25:40 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 18 subdomains ...
# 25:41 |   |INFO3|AdaptiveEnrichment: reducing ...
# 29:25 |   |INFO3|AdaptiveEnrichment: added 18 local basis functions, system size increase: 181 --> 199
# 29:25 |   |INFO3|AdaptiveEnrichment: estimated error 0.9569250304332773 above target error of 0.1437380405501575, enriching ...
# 29:25 |   |INFO3|AdaptiveEnrichment: marked 8/64 subdomains due to Dörfler marking
# 29:25 |   |INFO3|AdaptiveEnrichment:    and 7/56 additionally due to age marking
# 29:25 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 15 subdomains ...
# 29:25 |   |INFO3|AdaptiveEnrichment: reducing ...
# 33:11 |   |INFO3|AdaptiveEnrichment: added 15 local basis functions, system size increase: 199 --> 214
# 33:12 |   |INFO3|AdaptiveEnrichment: estimated error 0.5100126512665342 above target error of 0.1437380405501575, enriching ...
# 33:12 |   |INFO3|AdaptiveEnrichment: marked 12/64 subdomains due to Dörfler marking
# 33:12 |   |INFO3|AdaptiveEnrichment:    and 0/52 additionally due to age marking
# 33:12 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 12 subdomains ...
# 33:12 |   |INFO3|AdaptiveEnrichment: reducing ...
# 36:57 |   |INFO3|AdaptiveEnrichment: added 12 local basis functions, system size increase: 214 --> 226
# 36:57 |   |INFO3|AdaptiveEnrichment: estimated error 0.3896582114561017 above target error of 0.1437380405501575, enriching ...
# 36:57 |   |INFO3|AdaptiveEnrichment: marked 25/64 subdomains due to Dörfler marking
# 36:57 |   |INFO3|AdaptiveEnrichment:    and 12/39 additionally due to age marking
# 36:57 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 37 subdomains ...
# 36:57 |   |INFO3|AdaptiveEnrichment: reducing ...
# 40:44 |   |INFO3|AdaptiveEnrichment: added 37 local basis functions, system size increase: 226 --> 263
# 40:44 |   |INFO3|AdaptiveEnrichment: estimated error 0.3169394806588636 above target error of 0.1437380405501575, enriching ...
# 40:44 |   |INFO3|AdaptiveEnrichment: marked 17/64 subdomains due to Dörfler marking
# 40:44 |   |INFO3|AdaptiveEnrichment:    and 7/47 additionally due to age marking
# 40:44 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 24 subdomains ...
# 40:44 |   |INFO3|AdaptiveEnrichment: reducing ...
# 44:32 |   |INFO3|AdaptiveEnrichment: added 24 local basis functions, system size increase: 263 --> 287
# 44:32 |   |INFO3|AdaptiveEnrichment: estimated error 0.28622962801512625 above target error of 0.1437380405501575, enriching ...
# 44:32 |   |INFO3|AdaptiveEnrichment: marked 11/64 subdomains due to Dörfler marking
# 44:32 |   |INFO3|AdaptiveEnrichment:    and 8/53 additionally due to age marking
# 44:32 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 19 subdomains ...
# 44:32 |   |INFO3|AdaptiveEnrichment: reducing ...
# 48:22 |   |INFO3|AdaptiveEnrichment: added 19 local basis functions, system size increase: 287 --> 306
# 48:22 |   |INFO3|AdaptiveEnrichment: estimated error 0.2515724630269668 above target error of 0.1437380405501575, enriching ...
# 48:22 |   |INFO3|AdaptiveEnrichment: marked 10/64 subdomains due to Dörfler marking
# 48:22 |   |INFO3|AdaptiveEnrichment:    and 6/54 additionally due to age marking
# 48:22 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 16 subdomains ...
# 48:22 |   |INFO3|AdaptiveEnrichment: reducing ...
# 52:12 |   |INFO3|AdaptiveEnrichment: added 16 local basis functions, system size increase: 306 --> 322
# 52:12 |   |INFO3|AdaptiveEnrichment: estimated error 0.24469321389048662 above target error of 0.1437380405501575, enriching ...
# 52:12 |   |INFO3|AdaptiveEnrichment: marked 8/64 subdomains due to Dörfler marking
# 52:12 |   |INFO3|AdaptiveEnrichment:    and 24/56 additionally due to age marking
# 52:12 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 32 subdomains ...
# 52:13 |   |INFO3|AdaptiveEnrichment: reducing ...
# 56:04 |   |INFO3|AdaptiveEnrichment: added 32 local basis functions, system size increase: 322 --> 354
# 56:04 |   |INFO3|AdaptiveEnrichment: estimated error 0.23219514744524633 above target error of 0.1437380405501575, enriching ...
# 56:04 |   |INFO3|AdaptiveEnrichment: marked 8/64 subdomains due to Dörfler marking
# 56:04 |   |INFO3|AdaptiveEnrichment:    and 10/56 additionally due to age marking
# 56:04 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 18 subdomains ...
# 56:04 |   |INFO3|AdaptiveEnrichment: reducing ...
# 59:54 |   |INFO3|AdaptiveEnrichment: added 18 local basis functions, system size increase: 354 --> 372
# 59:54 |   |INFO3|AdaptiveEnrichment: estimated error 0.2271382986246981 above target error of 0.1437380405501575, enriching ...
# 59:54 |   |INFO3|AdaptiveEnrichment: marked 8/64 subdomains due to Dörfler marking
# 59:54 |   |INFO3|AdaptiveEnrichment:    and 13/56 additionally due to age marking
# 59:54 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 21 subdomains ...
# 59:55 |   |INFO3|AdaptiveEnrichment: reducing ...
#        \
#         \
#          \
# 01:03:47 |   |INFO3|AdaptiveEnrichment: added 21 local basis functions, system size increase: 372 --> 393
# 01:03:47 |   |INFO3|AdaptiveEnrichment: estimated error 0.21527993943339013 above target error of 0.1437380405501575, enriching ...
# 01:03:47 |   |INFO3|AdaptiveEnrichment: marked 9/64 subdomains due to Dörfler marking
# 01:03:47 |   |INFO3|AdaptiveEnrichment:    and 7/55 additionally due to age marking
# 01:03:47 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 16 subdomains ...
# 01:03:48 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:07:39 |   |INFO3|AdaptiveEnrichment: added 16 local basis functions, system size increase: 393 --> 409
# 01:07:39 |   |INFO3|AdaptiveEnrichment: estimated error 0.20014441156432508 above target error of 0.1437380405501575, enriching ...
# 01:07:39 |   |INFO3|AdaptiveEnrichment: marked 14/64 subdomains due to Dörfler marking
# 01:07:39 |   |INFO3|AdaptiveEnrichment:    and 22/50 additionally due to age marking
# 01:07:39 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 36 subdomains ...
# 01:07:40 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:11:33 |   |INFO3|AdaptiveEnrichment: added 36 local basis functions, system size increase: 409 --> 445
# 01:11:33 |   |INFO3|AdaptiveEnrichment: estimated error 0.17381362006772547 above target error of 0.1437380405501575, enriching ...
# 01:11:33 |   |INFO3|AdaptiveEnrichment: marked 22/64 subdomains due to Dörfler marking
# 01:11:33 |   |INFO3|AdaptiveEnrichment:    and 9/42 additionally due to age marking
# 01:11:33 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 31 subdomains ...
# 01:11:34 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:15:29 |   |INFO3|AdaptiveEnrichment: added 31 local basis functions, system size increase: 445 --> 476
# 01:15:29 |   |INFO3|AdaptiveEnrichment: estimated error 0.16785582560247958 above target error of 0.1437380405501575, enriching ...
# 01:15:29 |   |INFO3|AdaptiveEnrichment: marked 24/64 subdomains due to Dörfler marking
# 01:15:29 |   |INFO3|AdaptiveEnrichment:    and 7/40 additionally due to age marking
# 01:15:29 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 31 subdomains ...
# 01:15:30 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:19:26 |   |INFO3|AdaptiveEnrichment: added 31 local basis functions, system size increase: 476 --> 507
# 01:19:26 |   |INFO3|AdaptiveEnrichment: estimated error 0.16279641171385398 above target error of 0.1437380405501575, enriching ...
# 01:19:26 |   |INFO3|AdaptiveEnrichment: marked 24/64 subdomains due to Dörfler marking
# 01:19:26 |   |INFO3|AdaptiveEnrichment:    and 5/40 additionally due to age marking
# 01:19:26 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 29 subdomains ...
# 01:19:26 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:23:23 |   |INFO3|AdaptiveEnrichment: added 29 local basis functions, system size increase: 507 --> 536
# 01:23:23 |   |INFO3|AdaptiveEnrichment: estimated error 0.15879177172202805 above target error of 0.1437380405501575, enriching ...
# 01:23:23 |   |INFO3|AdaptiveEnrichment: marked 24/64 subdomains due to Dörfler marking
# 01:23:23 |   |INFO3|AdaptiveEnrichment:    and 14/40 additionally due to age marking
# 01:23:23 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 38 subdomains ...
# 01:23:24 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:27:23 |   |INFO3|AdaptiveEnrichment: added 38 local basis functions, system size increase: 536 --> 574
# 01:27:23 |   |INFO3|AdaptiveEnrichment: estimated error 0.15607299160794477 above target error of 0.1437380405501575, enriching ...
# 01:27:23 |   |INFO3|AdaptiveEnrichment: marked 25/64 subdomains due to Dörfler marking
# 01:27:23 |   |INFO3|AdaptiveEnrichment:    and 8/39 additionally due to age marking
# 01:27:23 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 33 subdomains ...
# 01:27:23 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:31:21 |   |INFO3|AdaptiveEnrichment: added 33 local basis functions, system size increase: 574 --> 607
# 01:31:21 |   |INFO3|AdaptiveEnrichment: estimated error 0.1525774512054836 above target error of 0.1437380405501575, enriching ...
# 01:31:21 |   |INFO3|AdaptiveEnrichment: marked 26/64 subdomains due to Dörfler marking
# 01:31:21 |   |INFO3|AdaptiveEnrichment:    and 8/38 additionally due to age marking
# 01:31:21 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 34 subdomains ...
# 01:31:22 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:35:18 |   |INFO3|AdaptiveEnrichment: added 34 local basis functions, system size increase: 607 --> 641
# 01:35:18 |   |INFO3|AdaptiveEnrichment: estimated error 0.1496758228384135 above target error of 0.1437380405501575, enriching ...
# 01:35:18 |   |INFO3|AdaptiveEnrichment: marked 29/64 subdomains due to Dörfler marking
# 01:35:18 |   |INFO3|AdaptiveEnrichment:    and 4/35 additionally due to age marking
# 01:35:18 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 33 subdomains ...
# 01:35:19 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:39:17 |   |INFO3|AdaptiveEnrichment: added 33 local basis functions, system size increase: 641 --> 674
# 01:39:17 |   |INFO3|AdaptiveEnrichment: estimated error 0.14338345732318133 below target error of 0.1437380405501575, no enrichment required ...
# 01:39:17 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:39:21 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [0.25000001, 0.5]} is 0.14373803970387838
# 01:39:21 AdaptiveEnrichment: solving 674-dimensional system for mu = {diffusion: [0.25000001, 0.5]} ...
# 01:39:21 |   |INFO3|AdaptiveEnrichment: estimated error 0.1433834565955592 below target error of 0.14373803970387838, no enrichment required ...
# 01:39:21 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:39:25 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [0.25, 0.50000001]} is 0.14373804041303131
# 01:39:25 AdaptiveEnrichment: solving 674-dimensional system for mu = {diffusion: [0.25, 0.50000001]} ...
# 01:39:25 |   |INFO3|AdaptiveEnrichment: estimated error 0.14338345709097716 below target error of 0.14373804041303131, no enrichment required ...
# 01:39:25 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:39:29 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.7340249917824622, 1.3817968133456588]} is 0.06842022177575724
# 01:39:29 AdaptiveEnrichment: solving 674-dimensional system for mu = {diffusion: [1.7340249917824622, 1.3817968133456588]} ...
# 01:39:29 |   |INFO3|AdaptiveEnrichment: estimated error 0.18109639316158938 above target error of 0.06842022177575724, enriching ...
# 01:39:29 |   |INFO3|AdaptiveEnrichment: marked 5/64 subdomains due to Dörfler marking
# 01:39:29 |   |INFO3|AdaptiveEnrichment:    and 0/59 additionally due to age marking
# 01:39:29 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 5 subdomains ...
# 01:39:30 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:43:48 |   |INFO3|AdaptiveEnrichment: added 5 local basis functions, system size increase: 674 --> 679
# 01:43:48 |   |INFO3|AdaptiveEnrichment: estimated error 0.126424338739359 above target error of 0.06842022177575724, enriching ...
# 01:43:48 |   |INFO3|AdaptiveEnrichment: marked 3/64 subdomains due to Dörfler marking
# 01:43:48 |   |INFO3|AdaptiveEnrichment:    and 0/61 additionally due to age marking
# 01:43:48 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 3 subdomains ...
# 01:43:49 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:47:54 |   |INFO3|AdaptiveEnrichment: added 3 local basis functions, system size increase: 679 --> 682
# 01:47:54 |   |INFO3|AdaptiveEnrichment: estimated error 0.08796075285404287 above target error of 0.06842022177575724, enriching ...
# 01:47:54 |   |INFO3|AdaptiveEnrichment: marked 24/64 subdomains due to Dörfler marking
# 01:47:54 |   |INFO3|AdaptiveEnrichment:    and 0/40 additionally due to age marking
# 01:47:54 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 24 subdomains ...
# 01:47:54 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:52:07 |   |INFO3|AdaptiveEnrichment: added 24 local basis functions, system size increase: 682 --> 706
# 01:52:07 |   |INFO3|AdaptiveEnrichment: estimated error 0.07134567180604735 above target error of 0.06842022177575724, enriching ...
# 01:52:07 |   |INFO3|AdaptiveEnrichment: marked 35/64 subdomains due to Dörfler marking
# 01:52:07 |   |INFO3|AdaptiveEnrichment:    and 17/29 additionally due to age marking
# 01:52:07 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 52 subdomains ...
# 01:52:08 |   |INFO3|AdaptiveEnrichment: reducing ...
# 01:57:08 |   |INFO3|AdaptiveEnrichment: added 52 local basis functions, system size increase: 706 --> 758
# 01:57:08 |   |INFO3|AdaptiveEnrichment: estimated error 0.06726774500217111 below target error of 0.06842022177575724, no enrichment required ...
# 01:57:08 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:57:13 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.734025001782462, 1.3817968133456588]} is 0.06842022182673425
# 01:57:13 AdaptiveEnrichment: solving 758-dimensional system for mu = {diffusion: [1.734025001782462, 1.3817968133456588]} ...
# 01:57:13 |   |INFO3|AdaptiveEnrichment: estimated error 0.06726774505079502 below target error of 0.06842022182673425, no enrichment required ...
# 01:57:13 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:57:18 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.7340249917824622, 1.3817968233456588]} is 0.06842022158470294
# 01:57:18 AdaptiveEnrichment: solving 758-dimensional system for mu = {diffusion: [1.7340249917824622, 1.3817968233456588]} ...
# 01:57:18 |   |INFO3|AdaptiveEnrichment: estimated error 0.06726774479299925 below target error of 0.06842022158470294, no enrichment required ...
# 01:57:18 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 01:57:23 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.9216170464430502, 2.4408280118715804]} is 0.06195881902581105
# 01:57:23 AdaptiveEnrichment: solving 758-dimensional system for mu = {diffusion: [1.9216170464430502, 2.4408280118715804]} ...
# 01:57:23 |   |INFO3|AdaptiveEnrichment: estimated error 0.06910087064012702 above target error of 0.06195881902581105, enriching ...
# 01:57:23 |   |INFO3|AdaptiveEnrichment: marked 8/64 subdomains due to Dörfler marking
# 01:57:23 |   |INFO3|AdaptiveEnrichment:    and 0/56 additionally due to age marking
# 01:57:23 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 8 subdomains ...
# 01:57:24 |   |INFO3|AdaptiveEnrichment: reducing ...
# 02:02:39 |   |INFO3|AdaptiveEnrichment: added 8 local basis functions, system size increase: 758 --> 766
# 02:02:39 |   |INFO3|AdaptiveEnrichment: estimated error 0.060131177840634945 below target error of 0.06195881902581105, no enrichment required ...
# 02:02:39 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:02:44 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.9216170564430501, 2.4408280118715804]} is 0.061958819107547504
# 02:02:44 AdaptiveEnrichment: solving 766-dimensional system for mu = {diffusion: [1.9216170564430501, 2.4408280118715804]} ...
# 02:02:45 |   |INFO3|AdaptiveEnrichment: estimated error 0.06013117790237371 below target error of 0.061958819107547504, no enrichment required ...
# 02:02:45 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:02:49 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.9216170464430502, 2.4408280218715803]} is 0.06195881914561901
# 02:02:49 AdaptiveEnrichment: solving 766-dimensional system for mu = {diffusion: [1.9216170464430502, 2.4408280218715803]} ...
# 02:02:50 |   |INFO3|AdaptiveEnrichment: estimated error 0.06013117790593882 below target error of 0.06195881914561901, no enrichment required ...
# 02:02:50 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:02:55 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.6688057199443032, 3.141592653589793]} is 0.07151702891687009
# 02:02:55 AdaptiveEnrichment: solving 766-dimensional system for mu = {diffusion: [1.6688057199443032, 3.141592653589793]} ...
# 02:02:55 |   |INFO3|AdaptiveEnrichment: estimated error 0.07375778528064889 above target error of 0.07151702891687009, enriching ...
# 02:02:55 |   |INFO3|AdaptiveEnrichment: marked 7/64 subdomains due to Dörfler marking
# 02:02:55 |   |INFO3|AdaptiveEnrichment:    and 0/57 additionally due to age marking
# 02:02:55 |   |INFO3|AdaptiveEnrichment: solving local corrector problems on 7 subdomains ...
# 02:02:55 |   |INFO3|AdaptiveEnrichment: reducing ...
# 02:07:52 |   |INFO3|AdaptiveEnrichment: added 7 local basis functions, system size increase: 766 --> 773
# 02:07:52 |   |INFO3|AdaptiveEnrichment: estimated error 0.069810883033049 below target error of 0.07151702891687009, no enrichment required ...
# 02:07:52 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:07:57 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.668805729944303, 3.141592653589793]} is 0.07151702895501531
# 02:07:57 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.668805729944303, 3.141592653589793]} ...
# 02:07:58 |   |INFO3|AdaptiveEnrichment: estimated error 0.06981088305120266 below target error of 0.07151702895501531, no enrichment required ...
# 02:07:58 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:04 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.6688057199443032, 3.141592663589793]} is 0.07151702918143003
# 02:08:04 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.6688057199443032, 3.141592663589793]} ...
# 02:08:04 |   |INFO3|AdaptiveEnrichment: estimated error 0.06981088329243303 below target error of 0.07151702918143003, no enrichment required ...
# 02:08:04 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:09 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.6014340417900574, 3.141592653589793]} is 0.07140062677550915
# 02:08:09 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.6014340417900574, 3.141592653589793]} ...
# 02:08:09 |   |INFO3|AdaptiveEnrichment: estimated error 0.0697038670734717 below target error of 0.07140062677550915, no enrichment required ...
# 02:08:09 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:14 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.6014340517900574, 3.141592653589793]} is 0.07140062679062403
# 02:08:14 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.6014340517900574, 3.141592653589793]} ...
# 02:08:15 |   |INFO3|AdaptiveEnrichment: estimated error 0.06970386707403062 below target error of 0.07140062679062403, no enrichment required ...
# 02:08:15 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:21 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.6014340417900574, 3.141592663589793]} is 0.0714006270069724
# 02:08:21 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.6014340417900574, 3.141592663589793]} ...
# 02:08:21 |   |INFO3|AdaptiveEnrichment: estimated error 0.06970386731932886 below target error of 0.0714006270069724, no enrichment required ...
# 02:08:21 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:26 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5710095328805258, 3.141592653589793]} is 0.07138803786594242
# 02:08:26 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5710095328805258, 3.141592653589793]} ...
# 02:08:27 |   |INFO3|AdaptiveEnrichment: estimated error 0.06969229497538218 below target error of 0.07138803786594242, no enrichment required ...
# 02:08:27 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:31 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5710095428805257, 3.141592653589793]} is 0.07138803784236308
# 02:08:31 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5710095428805257, 3.141592653589793]} ...
# 02:08:31 |   |INFO3|AdaptiveEnrichment: estimated error 0.0696922949818141 below target error of 0.07138803784236308, no enrichment required ...
# 02:08:31 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:36 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5710095328805258, 3.141592663589793]} is 0.07138803810197818
# 02:08:36 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5710095328805258, 3.141592663589793]} ...
# 02:08:36 |   |INFO3|AdaptiveEnrichment: estimated error 0.06969229523154166 below target error of 0.07138803810197818, no enrichment required ...
# 02:08:36 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:40 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5707974600646613, 3.141592653589793]} is 0.07138803725673762
# 02:08:40 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5707974600646613, 3.141592653589793]} ...
# 02:08:40 |   |INFO3|AdaptiveEnrichment: estimated error 0.06969229442520494 below target error of 0.07138803725673762, no enrichment required ...
# 02:08:40 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:44 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5707974700646612, 3.141592653589793]} is 0.07138803726270902
# 02:08:44 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5707974700646612, 3.141592653589793]} ...
# 02:08:44 |   |INFO3|AdaptiveEnrichment: estimated error 0.06969229442811492 below target error of 0.07138803726270902, no enrichment required ...
# 02:08:44 |INFO3|AdaptiveEnrichment: estimating discretization error:
# .
# 02:08:48 |INFO3|AdaptiveEnrichment:   target error for mu = {diffusion: [1.5707974600646613, 3.141592663589793]} is 0.07138803748739661
# 02:08:48 AdaptiveEnrichment: solving 773-dimensional system for mu = {diffusion: [1.5707974600646613, 3.141592663589793]} ...
# 02:08:48 |   |INFO3|AdaptiveEnrichment: estimated error 0.06969229467696614 below target error of 0.07138803748739661, no enrichment required ...
#
# 02:08:48 notebook:  succeded!
# 02:08:48 notebook:   mu_min:    {diffusion: [1.5707974600646613, 3.141592653589793]}
# 02:08:48 notebook:   QoI(mu_min): 1.2439976508561412
# 02:08:48 notebook:   num iterations:     6
# 02:08:48 notebook:   num function calls: 21

# %%
adaptive_LRBMS_minimizer = result.x
adaptive_LRBMS_minimum = result.fun

logger.info('')
logger.info('relative LRBMS (adaptive) minimizer error: {}'.format(
    (np.linalg.norm(reference_minimizer - adaptive_LRBMS_minimizer)/np.linalg.norm(reference_minimizer))))
logger.info('relative LRBMS (adaptive) QoI error:   {}'.format(
    (np.abs(reference_minimum - adaptive_LRBMS_minimum)/np.abs(reference_minimum))[0]))
# Out:
#
# 02:08:49 notebook: relative LRBMS (adaptive) minimizer error: 4.5040761546104006e-05
# 02:08:49 notebook: relative LRBMS (adaptive) QoI error:   1.3638742142753902e-05

# %% [markdown]
# Lets take a look at the selected mus during the minimization.
# * the orange bars indicate the mus selcted by the minimizer
# * the orange dots indicate the computed QoI during the adaptive enrichment (these are not returned to the minimizer, larger ones were computed first)
# * the purple dots indicate those values of the QoI returned to the minimizer

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

x, y, f_of_x = compute_value_matrix(reference_quantity_of_interest, XX, YY)
ax.plot_surface(x, y, f_of_x, cmap='Purples', linewidth=0, antialiased=False, alpha=0.5)

intermediate_mus = list(adaptive_LRBMS_minimization_data['intermediate_evaluation_points'])
intermediate_QoIs = list(adaptive_LRBMS_minimization_data['intermediate_evaluations'])
sizes = 40*np.exp(np.linspace(1, 0.01, len(intermediate_mus)))

for ii in range(len(intermediate_mus)):
    mu = intermediate_mus[ii]
    QoI = intermediate_QoIs[ii]
    addplot_xy_point_as_bar(ax, mu[0], mu[1])
    # x and y need to be interchanged here to match the surface plot
    ax.scatter(mu[1], mu[0], QoI, c='orange',s=sizes[ii])

mus = list(adaptive_LRBMS_minimization_data['evaluation_points'])
QoIs = list(adaptive_LRBMS_minimization_data['evaluations'])

for ii in range(len(mus)):
    mu = mus[ii]
    QoI = QoIs[ii]
    addplot_xy_point_as_bar(ax, mu[0], mu[1])
    # x and y need to be interchanged here to match the surface plot
    ax.scatter(mu[1], mu[0], QoI, c='purple')

ax.view_init(elev=57.7597402597, azim=-59.6370967742)
ax.set_xlim3d([-0.10457963, 3.2961723])
ax.set_ylim3d([-0.10457963, 3.29617229])
intermediate_QoIs.append(1.21122592)
intermediate_QoIs.append(4.42022848)
ax.set_zlim3d([np.min(intermediate_QoIs), np.max(intermediate_QoIs)])
# Out:
# (array([ 0.21921607]), 4.42022848)

# %%
extended_report(adaptive_LRBMS_minimization_data)

logger.info('total num_local_solves: {}'.format(np.sum(adaptive_LRBMS_minimization_data['num_local_solves'])))
# Out:
# 02:08:56 notebook: num_evals
# 02:08:56 notebook:   21
#
# 02:08:56 notebook: evaluation_points
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25000000999999999, 0.5]
# 02:08:56 notebook:   [0.25, 0.50000001000000005]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340250017824621, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968233456588]
# 02:08:56 notebook:   [1.9216170464430502, 2.4408280118715804]
# 02:08:56 notebook:   [1.9216170564430501, 2.4408280118715804]
# 02:08:56 notebook:   [1.9216170464430502, 2.4408280218715803]
# 02:08:56 notebook:   [1.6688057199443032, 3.1415926535897931]
# 02:08:56 notebook:   [1.6688057299443031, 3.1415926535897931]
# 02:08:56 notebook:   [1.6688057199443032, 3.1415926635897931]
# 02:08:56 notebook:   [1.6014340417900574, 3.1415926535897931]
# 02:08:56 notebook:   [1.6014340517900574, 3.1415926535897931]
# 02:08:56 notebook:   [1.6014340417900574, 3.1415926635897931]
# 02:08:56 notebook:   [1.5710095328805258, 3.1415926535897931]
# 02:08:56 notebook:   [1.5710095428805257, 3.1415926535897931]
# 02:08:56 notebook:   [1.5710095328805258, 3.1415926635897931]
# 02:08:56 notebook:   [1.5707974600646613, 3.1415926535897931]
# 02:08:56 notebook:   [1.5707974700646612, 3.1415926535897931]
# 02:08:56 notebook:   [1.5707974600646613, 3.1415926635897931]
#
# 02:08:56 notebook: evaluations
# 02:08:56 notebook:   3.9715825297222405
# 02:08:56 notebook:   3.9715825148819905
# 02:08:56 notebook:   3.9715825209042723
# 02:08:56 notebook:   2.0202872028988965
# 02:08:56 notebook:   2.0202872046381906
# 02:08:56 notebook:   2.0202871951548564
# 02:08:56 notebook:   1.5067646408057824
# 02:08:56 notebook:   1.5067646443411833
# 02:08:56 notebook:   1.5067646371856749
# 02:08:56 notebook:   1.2482509006856484
# 02:08:56 notebook:   1.248250901555883
# 02:08:56 notebook:   1.2482508983392213
# 02:08:56 notebook:   1.2444122768223957
# 02:08:56 notebook:   1.2444122770931267
# 02:08:56 notebook:   1.2444122744793185
# 02:08:56 notebook:   1.243997670929404
# 02:08:56 notebook:   1.243997670931278
# 02:08:56 notebook:   1.2439976685866914
# 02:08:56 notebook:   1.2439976508561412
# 02:08:56 notebook:   1.2439976508561545
# 02:08:56 notebook:   1.2439976485134279
#
# 02:08:56 notebook: intermediate_evaluations
# 02:08:56 notebook:   [ 0.21921607]
# 02:08:56 notebook:   [ 1.01151721]
# 02:08:56 notebook:   [ 2.53172007]
# 02:08:56 notebook:   [ 3.01320536]
# 02:08:56 notebook:   [ 3.6286402]
# 02:08:56 notebook:   [ 3.90468128]
# 02:08:56 notebook:   [ 3.94063221]
# 02:08:56 notebook:   [ 3.96706437]
# 02:08:56 notebook:   [ 3.96931581]
# 02:08:56 notebook:   [ 3.97067123]
# 02:08:56 notebook:   [ 3.97102618]
# 02:08:56 notebook:   [ 3.97121902]
# 02:08:56 notebook:   [ 3.97125704]
# 02:08:56 notebook:   [ 3.9713278]
# 02:08:56 notebook:   [ 3.97136505]
# 02:08:56 notebook:   [ 3.97140576]
# 02:08:56 notebook:   [ 3.97143889]
# 02:08:56 notebook:   [ 3.97151759]
# 02:08:56 notebook:   [ 3.97153299]
# 02:08:56 notebook:   [ 3.97154474]
# 02:08:56 notebook:   [ 3.97155298]
# 02:08:56 notebook:   [ 3.97156034]
# 02:08:56 notebook:   [ 3.97156571]
# 02:08:56 notebook:   [ 3.97157014]
# 02:08:56 notebook:   [ 3.97158253]
# 02:08:56 notebook:   [ 3.97158251]
# 02:08:56 notebook:   [ 3.97158252]
# 02:08:56 notebook:   [ 2.01764724]
# 02:08:56 notebook:   [ 2.01952651]
# 02:08:56 notebook:   [ 2.02018292]
# 02:08:56 notebook:   [ 2.02027495]
# 02:08:56 notebook:   [ 2.0202872]
# 02:08:56 notebook:   [ 2.0202872]
# 02:08:56 notebook:   [ 2.0202872]
# 02:08:56 notebook:   [ 1.50667625]
# 02:08:56 notebook:   [ 1.50676464]
# 02:08:56 notebook:   [ 1.50676464]
# 02:08:56 notebook:   [ 1.50676464]
# 02:08:56 notebook:   [ 1.24820839]
# 02:08:56 notebook:   [ 1.2482509]
# 02:08:56 notebook:   [ 1.2482509]
# 02:08:56 notebook:   [ 1.2482509]
# 02:08:56 notebook:   [ 1.24441228]
# 02:08:56 notebook:   [ 1.24441228]
# 02:08:56 notebook:   [ 1.24441227]
# 02:08:56 notebook:   [ 1.24399767]
# 02:08:56 notebook:   [ 1.24399767]
# 02:08:56 notebook:   [ 1.24399767]
# 02:08:56 notebook:   [ 1.24399765]
# 02:08:56 notebook:   [ 1.24399765]
# 02:08:56 notebook:   [ 1.24399765]
#
# 02:08:56 notebook: intermediate_evaluation_points
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25, 0.5]
# 02:08:56 notebook:   [0.25000000999999999, 0.5]
# 02:08:56 notebook:   [0.25, 0.50000001000000005]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340250017824621, 1.3817968133456588]
# 02:08:56 notebook:   [1.7340249917824622, 1.3817968233456588]
# 02:08:56 notebook:   [1.9216170464430502, 2.4408280118715804]
# 02:08:56 notebook:   [1.9216170464430502, 2.4408280118715804]
# 02:08:56 notebook:   [1.9216170564430501, 2.4408280118715804]
# 02:08:56 notebook:   [1.9216170464430502, 2.4408280218715803]
# 02:08:56 notebook:   [1.6688057199443032, 3.1415926535897931]
# 02:08:56 notebook:   [1.6688057199443032, 3.1415926535897931]
# 02:08:56 notebook:   [1.6688057299443031, 3.1415926535897931]
# 02:08:56 notebook:   [1.6688057199443032, 3.1415926635897931]
# 02:08:56 notebook:   [1.6014340417900574, 3.1415926535897931]
# 02:08:56 notebook:   [1.6014340517900574, 3.1415926535897931]
# 02:08:56 notebook:   [1.6014340417900574, 3.1415926635897931]
# 02:08:56 notebook:   [1.5710095328805258, 3.1415926535897931]
# 02:08:56 notebook:   [1.5710095428805257, 3.1415926535897931]
# 02:08:56 notebook:   [1.5710095328805258, 3.1415926635897931]
# 02:08:56 notebook:   [1.5707974600646613, 3.1415926535897931]
# 02:08:56 notebook:   [1.5707974700646612, 3.1415926535897931]
# 02:08:56 notebook:   [1.5707974600646613, 3.1415926635897931]
#
# 02:08:56 notebook: num_local_solves
# 02:08:56 notebook:   610
# 02:08:56 notebook:   0
# 02:08:56 notebook:   0
# 02:08:56 notebook:   84
# 02:08:56 notebook:   0
# 02:08:56 notebook:   0
# 02:08:56 notebook:   8
# 02:08:56 notebook:   0
# 02:08:56 notebook:   0
# 02:08:56 notebook:   7
# 02:08:56 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
# 02:08:57 notebook:   0
#
# 02:08:57 notebook: total num_local_solves: 709

# %% [markdown]
# Lets take a look at the size of the local reduced basis at the end of the simulation.

# %%
for ss in range(grid.num_subdomains):
    print('{}: {}'.format(ss, len(online_adaptive_LRBMS.reductor.bases['domain_{}'.format(ss)])))
# Out:
# 0: 18
# 1: 22
# 2: 12
# 3: 11
# 4: 14
# 5: 11
# 6: 17
# 7: 19
# 8: 21
# 9: 15
# 10: 13
# 11: 9
# 12: 9
# 13: 8
# 14: 10
# 15: 18
# 16: 13
# 17: 13
# 18: 13
# 19: 8
# 20: 9
# 21: 9
# 22: 8
# 23: 11
# 24: 14
# 25: 9
# 26: 9
# 27: 9
# 28: 8
# 29: 9
# 30: 8
# 31: 13
# 32: 15
# 33: 10
# 34: 8
# 35: 8
# 36: 8
# 37: 9
# 38: 8
# 39: 13
# 40: 12
# 41: 11
# 42: 13
# 43: 8
# 44: 9
# 45: 9
# 46: 8
# 47: 12
# 48: 19
# 49: 14
# 50: 13
# 51: 10
# 52: 8
# 53: 8
# 54: 9
# 55: 17
# 56: 20
# 57: 18
# 58: 11
# 59: 13
# 60: 12
# 61: 13
# 62: 18
# 63: 19

# %%
subdomains = config['num_coarse_grid_elements']
basis_sizes = np.ones(subdomains)
counter = 0
for ii in range(subdomains[0]):
    for jj in range(subdomains[1]):
        basis_sizes[subdomains[0] - 1 - ii][jj] = len(online_adaptive_LRBMS.reductor.bases['domain_{}'.format(counter)])
        counter += 1
min_size = np.min([len(online_adaptive_LRBMS.reductor.bases['domain_{}'.format(ss)]) for ss in range(grid.num_subdomains)])
max_size = np.max([len(online_adaptive_LRBMS.reductor.bases['domain_{}'.format(ss)]) for ss in range(grid.num_subdomains)])
logger.info('sizes of the local reduced bases (min/max): {}/{}'.format(min_size, max_size))
plt.matshow(basis_sizes, cmap=cm.get_cmap('Purples', max_size - min_size + 1))
plt.colorbar()
# Out:
# 02:08:57 notebook: size of the local reduced basis (min/max): 8/22

# %% [markdown]
# To conclude: using the online adaptive LRBMS with an initial $Q^0$ basis
# * finds the minimizer up to a relative $l_2$-error of 4.5e-05
# * finds the minimum up to a relative error of 1.36e-05
# * needs 0 global SWIPDG evaluations
# * needs 709 local corrector problem solutions
# * the sizes of the final local reduced bases indicate the spatial influence of the parameter dependency
